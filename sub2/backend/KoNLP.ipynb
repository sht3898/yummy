# %% [markdown]
# # TF-IDF 실습

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


doc_list = [
    '프리시즌 아시아 투어를 떠나는 토트넘은 싱가포르, 중국을 차례로 방문해 ICC 경기를 치른다.',
    '영국 "풋볼 런던"은 11일 "토트넘이 ICC 첫 경기에서 가장 강력한 스쿼드로 유벤투스에 맞설 것"이라고 평가했다.',
    '토트넘에 합류하는 손흥민은 유벤투스전 출전을 목표로 구슬땀을 흘릴 예정이다.',
]

tfidf_vectorizer = TfidfVectorizer(min_df=1)
tfidf_matrix = tfidf_vectorizer.fit_transform(doc_list)
doc_similarities = (tfidf_matrix * tfidf_matrix.T)

print(doc_similarities.toarray())
# Out:
# [[1.         0.04612956 0.        ]
#  [0.04612956 1.         0.        ]
#  [0.         0.         1.        ]]

# %%
from konlpy.tag import Okt


okt = Okt()

doc_nouns_list = [' '.join(okt.nouns(doc)) for doc in doc_list]
print(doc_nouns_list)

tfidf_vectorizer = TfidfVectorizer(min_df=1)
tfidf_matrix = tfidf_vectorizer.fit_transform(doc_nouns_list)
doc_nouns_similarities = (tfidf_matrix * tfidf_matrix.T)

print(doc_nouns_similarities.toarray())
# Out:
# ['프리 시즌 아시아 투어 토트넘 싱가포르 중국 차례 방문 경기', '영국 풋볼 런던 은 토트넘 첫 경기 가장 스 쿼드로 유벤투스 것 평가', '토트넘 합류 손흥민 유벤투스 전 출전 목표 구슬 땀 예정']
# [[1.         0.11327504 0.04435806]
#  [0.11327504 1.         0.12859167]
#  [0.04435806 0.12859167 1.        ]]

# %% [markdown]
# # KoNLP 활용 리뷰 분류

# %% [markdown]
# ## 필요한 정보 불러오기

# %%
import sqlite3
import pandas as pd
import numpy as np
import sklearn
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from konlpy.tag import Kkma
from konlpy.tag import Okt
from konlpy.utils import pprint
import json
import pickle

# %%
con = sqlite3.connect("db.sqlite3")
cur = con.cursor()
# read table 
df_store = pd.read_sql_query("SELECT * from api_store", con)
df_review = pd.read_sql_query("SELECT * from api_storereview", con)

# clonse DB connection
con.close()

# %%
df_review.head()
# Out:
#    id  total_score                                            content  \
# 0   1          5.0         전포 윗길에 새로 생긴! 호주에서 온 쉐프가 직접 요리하는 호주식 레스토랑!
# 1   2          5.0                    샌드위치 내용물도 알차게 들어있고 맛있었어요 가성비 추천
# 2   3          4.0  홈플러스 1층 매장 푸드코트 내 있는 매장인데 계란찜정식은 처음보고 시켜봣는데 사진...
# 3   4          2.0  전 여기 5년전에 가봤었는데 그때 기억은 별로였어요\n단체손님이 많았고, 차려지는건...
# 4   5          3.0  친구들끼리 술 간단하게마시러 감. 스끼다시 괜찮지만 회 양이 조금 부족한 느낌. 맛...
#
#                      reg_time  store_id  user_id
# 0  2020-04-28 09:17:35.263075        15    68632
# 1  2020-04-28 09:17:35.263075        18   389728
# 2  2020-04-28 09:17:35.263075        19    68716
# 3  2020-04-28 09:17:35.263075        37   774353
# 4  2020-04-28 09:17:35.263075        38   115682

# %%
df_store.head()
# Out:
#    id     store_name branch  area            tel                address  \
# 0   1           Agal    nan    홍대  010-6689-5886   서울특별시 마포구 동교동 170-13
# 1   2         Assisy    nan    광주   062-367-0700    광주광역시 서구 농성동 631-33
# 2   3  Battered Sole    nan   이태원    02-749-6867   서울특별시 용산구 이태원동 118-9
# 3   4      Chakyoung    nan  달맞이길   051-756-5566  부산광역시 해운대구 중2동 1509-5
# 4   5       Delabobo    nan   발산역   02-2667-9854      서울특별시 강서구 등촌동 689
#
#     latitude   longitude   category  review_count  review_total_score   addr
# 0  37.556862  126.926666   아구찜|포장마차             0                   0  서울특별시
# 1  35.150746  126.890062         카페             0                   0  광주광역시
# 2  37.535032  126.991664    피쉬앤칩스|펍             0                   0  서울특별시
# 3  35.158587  129.175004  레스토랑|카프레제             0                   0  부산광역시
# 4  37.559904  126.840512  디저트카페|디저트             0                   0  서울특별시

# %%
df_store = df_store[df_store["addr"]=="충청북도 충주시"]

# %%
cities = set(df_store["addr"])

# %%
cities
# Out:
# {'강원도 강릉시',
#  '강원도 고성군',
#  '강원도 동해시',
#  '강원도 삼척시',
#  '강원도 속초시',
#  '강원도 양구군',
#  '강원도 양양군',
#  '강원도 영월군',
#  '강원도 원주시',
#  '강원도 인제군',
#  '강원도 정선군',
#  '강원도 철원군',
#  '강원도 춘천시',
#  '강원도 태백시',
#  '강원도 평창군',
#  '강원도 홍천군',
#  '강원도 화천군',
#  '강원도 횡성군',
#  '경기도 가평군',
#  '경기도 고양시',
#  '경기도 과천시',
#  '경기도 광명시',
#  '경기도 구리시',
#  '경기도 군포시',
#  '경기도 김포시',
#  '경기도 남양주시',
#  '경기도 동두천시',
#  '경기도 부천시',
#  '경기도 성남시',
#  '경기도 수원시',
#  '경기도 시흥시',
#  '경기도 안산시',
#  '경기도 안성시',
#  '경기도 안양시',
#  '경기도 양주시',
#  '경기도 양평군',
#  '경기도 여주시',
#  '경기도 연천군',
#  '경기도 오산시',
#  '경기도 용인시',
#  '경기도 의왕시',
#  '경기도 의정부시',
#  '경기도 이천시',
#  '경기도 파주시',
#  '경기도 평택시',
#  '경기도 포천시',
#  '경기도 하남시',
#  '경기도 화성시',
#  '경상남도 거제시',
#  '경상남도 거창군',
#  '경상남도 고성군',
#  '경상남도 김해시',
#  '경상남도 남해군',
#  '경상남도 밀양시',
#  '경상남도 사천시',
#  '경상남도 산청군',
#  '경상남도 양산시',
#  '경상남도 의령군',
#  '경상남도 진주시',
#  '경상남도 창녕군',
#  '경상남도 창원시',
#  '경상남도 통영시',
#  '경상남도 하동군',
#  '경상남도 함안군',
#  '경상남도 함양군',
#  '경상남도 합천군',
#  '경상북도 경산시',
#  '경상북도 경주시',
#  '경상북도 고령군',
#  '경상북도 구미시',
#  '경상북도 군위군',
#  '경상북도 김천시',
#  '경상북도 문경시',
#  '경상북도 봉화군',
#  '경상북도 상주시',
#  '경상북도 성주군',
#  '경상북도 안동시',
#  '경상북도 영덕군',
#  '경상북도 영양군',
#  '경상북도 영주시',
#  '경상북도 영천시',
#  '경상북도 예천군',
#  '경상북도 울릉군',
#  '경상북도 울진군',
#  '경상북도 의성군',
#  '경상북도 청도군',
#  '경상북도 청송군',
#  '경상북도 칠곡군',
#  '경상북도 포항시',
#  '광주광역시',
#  '대구광역시',
#  '대전광역시',
#  '부산광역시',
#  '서울특별시',
#  '세종특별자치시',
#  '울산광역시',
#  '인천광역시',
#  '전라남도 강진군',
#  '전라남도 고흥군',
#  '전라남도 곡성군',
#  '전라남도 광양시',
#  '전라남도 구례군',
#  '전라남도 나주시',
#  '전라남도 담양군',
#  '전라남도 목포시',
#  '전라남도 무안군',
#  '전라남도 보성군',
#  '전라남도 순천시',
#  '전라남도 신안군',
#  '전라남도 여수시',
#  '전라남도 영광군',
#  '전라남도 영암군',
#  '전라남도 완도군',
#  '전라남도 장성군',
#  '전라남도 장흥군',
#  '전라남도 진도군',
#  '전라남도 함평군',
#  '전라남도 해남군',
#  '전라남도 화순군',
#  '전라북도 고창군',
#  '전라북도 군산시',
#  '전라북도 김제시',
#  '전라북도 남원시',
#  '전라북도 무주군',
#  '전라북도 부안군',
#  '전라북도 순창군',
#  '전라북도 완주군',
#  '전라북도 익산시',
#  '전라북도 임실군',
#  '전라북도 장수군',
#  '전라북도 전주시',
#  '전라북도 정읍시',
#  '전라북도 진안군',
#  '제주특별자치도',
#  '충청남도 계룡시',
#  '충청남도 공주시',
#  '충청남도 금산군',
#  '충청남도 논산시',
#  '충청남도 당진시',
#  '충청남도 보령시',
#  '충청남도 부여군',
#  '충청남도 서산시',
#  '충청남도 서천군',
#  '충청남도 아산시',
#  '충청남도 예산군',
#  '충청남도 천안시',
#  '충청남도 청양군',
#  '충청남도 태안군',
#  '충청남도 홍성군',
#  '충청북도 괴산군',
#  '충청북도 단양군',
#  '충청북도 보은군',
#  '충청북도 영동군',
#  '충청북도 옥천군',
#  '충청북도 음성군',
#  '충청북도 제천시',
#  '충청북도 증평군',
#  '충청북도 진천군',
#  '충청북도 청주시',
#  '충청북도 충주시'}

# %%
# select some columns
stores = df_store[['id','store_name', 'area', 'category']]
reviews = df_review[['user_id','store_id','total_score', 'content']]

# rename columns and return data
reviews.rename(columns={'total_score':'rating'}, inplace=True)
stores.rename(columns={'id':'store_id'},inplace=True)

# %%
reviews.head()
# Out:
#    user_id  store_id  rating  \
# 0    68632        15     5.0
# 1   389728        18     5.0
# 2    68716        19     4.0
# 3   774353        37     2.0
# 4   115682        38     3.0
#
#                                              content
# 0         전포 윗길에 새로 생긴! 호주에서 온 쉐프가 직접 요리하는 호주식 레스토랑!
# 1                    샌드위치 내용물도 알차게 들어있고 맛있었어요 가성비 추천
# 2  홈플러스 1층 매장 푸드코트 내 있는 매장인데 계란찜정식은 처음보고 시켜봣는데 사진...
# 3  전 여기 5년전에 가봤었는데 그때 기억은 별로였어요\n단체손님이 많았고, 차려지는건...
# 4  친구들끼리 술 간단하게마시러 감. 스끼다시 괜찮지만 회 양이 조금 부족한 느낌. 맛...

# %%
stores.head()
# Out:
#       store_id    store_name area       category
# 427        428          13스시   충주        차돌박이|초밥
# 454        455        153낙지유   충주        연포탕|산낙지
# 892        893         1미터피자   충주            nan
# 1133      1134          21세기  교현동            nan
# 1485      1486  24시전주명가콩나물국밥   충주  콩나물국밥|전주콩나물국밥

# %%
stores[["store_id", "store_name"]]
# Out:
#         store_id    store_name
# 427          428          13스시
# 454          455        153낙지유
# 892          893         1미터피자
# 1133        1134          21세기
# 1485        1486  24시전주명가콩나물국밥
# ...          ...           ...
# 459107    459212          해피돈스
# 459191    459296        해피오네치킨
# 459192    459297        해피오네치킨
# 459194    459299        해피오네치킨
# 459809    459914       행복담는국수집
#
# [1291 rows x 2 columns]

# %%
reviews = pd.merge(stores, reviews, how='outer')

# %%
reviews.head()
# Out:
#    store_id    store_name area       category  user_id  rating content
# 0       428          13스시   충주        차돌박이|초밥      NaN     NaN     NaN
# 1       455        153낙지유   충주        연포탕|산낙지      NaN     NaN     NaN
# 2       893         1미터피자   충주            nan      NaN     NaN     NaN
# 3      1134          21세기  교현동            nan      NaN     NaN     NaN
# 4      1486  24시전주명가콩나물국밥   충주  콩나물국밥|전주콩나물국밥      NaN     NaN     NaN

# %% [markdown]
# ## 벡터화

# %%
store_content = {}
kkma = Kkma()
okt = Okt()

# %%
store_content = {}
for idx, review in reviews.iterrows():
    if review['content']:
        content = [noun for noun in (kkma.nouns(f"u{review['content']}"))]
        categories = kkma.nouns(f"u{review['category']}")
        for c in categories:
            content.append(c)
        content.append(review['area'])
        if store_content[review['store_id']]:
            store_content[review['store_id']] = content
        else:
            store_content[review['store_id']] = content

# %%
store_content = {}
for idx, review in reviews.iterrows():
    if review['content']:
        content = [noun for noun in (kkma.nouns(f"u{review['content']}"))]
        content.extend(kkma.nouns(f"u{review['category']}"))
        content.append(review['area'])
        store_content[review['store_id']] = content

# %%
new_store_content = {}
for idx, review in reviews.iterrows():
    if review['content']:
        content = [noun for noun in (kkma.nouns(f"u{review['content']}"))]
        content.extend(kkma.nouns(f"u{review['category']}"))
        content.append(review['area'])
        if new_store_content.get(review['store_id']):
            new_store_content[review['store_id']].extend(content)
        else:
            new_store_content[review['store_id']] = content
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-20eb243a6772> in <module>
#       2 for idx, review in reviews.iterrows():
#       3     if review['content']:
# ----> 4         content = [noun for noun in (kkma.nouns(f"u{review['content']}"))]
#       5         content.extend(kkma.nouns(f"u{review['category']}"))
#       6         content.append(review['area'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_kkma.py in nouns(self, phrase)
#      42         """Noun extractor."""
#      43
# ---> 44         nouns = self.jki.extractNoun(phrase)
#      45         if not nouns: return []
#      46         return [nouns.get(i).getString() for i in range(nouns.size())]
#
# KeyboardInterrupt:

# %%
print(len(new_store_content))
# Out:
# 456599

# %%
for key, item in store_content.items():
    print(f'{key} : {item}')

# %%
with open('kdump.json', 'w', encoding='utf-8') as make_file:
    json.dump(new_store_content, make_file, indent="\t")

# %%
with open('kdump.json', 'r') as f:
    json_data = json.load(f)

# %%
i = 0
for key, item in json_data.items():
    print(f'{key} : {item}')

# %%
json_data
# Out:
# {'1': ['아구', '아구찜', '찜', '포장마차', '홍대'],
#  '2': ['카페', '광주'],
#  '3': ['피', '피쉬앤칩스', '쉬', '앤', '칩스', '펍', '이태원'],
#  '4': ['레스토랑', '카프', '카프레', '레', '달맞이길'],
#  '5': ['디저트', '디저트카페', '카페', '발산역'],
#  '6': ['펍', '하남'],
#  '7': ['마들렌', '베이커리', '만촌동'],
#  '8': ['남포동'],
#  '9': ['고', '고깃집', '깃', '집', '고기', '고기집', '진주'],
#  '10': ['중식', '레스토랑', '신촌'],
#  '11': ['국수', '고기', '고기국수', '월곶'],
#  '12': ['역삼역'],
#  '13': ['수영역'],
#  '14': ['오뎅', '오뎅탕', '탕', '참치', '유성'],
#  '15': ['전포',
#   '윗길',
#   '호주',
#   '쉐프',
#   '요리',
#   '호',
#   '호주식',
#   '주식',
#   '레스토랑',
#   '호주',
#   '호주레스토랑',
#   '레스토랑',
#   '전포동'],
#  '16': ['에스프레소', '사당'],
#  '17': ['건대'],
#  '18': ['샌드위치', '내용물', '성비', '추천', '샌드위치', '쥬스', '전주'],
#  '19': ['홈',
#   '홈플러스',
#   '플러스',
#   '1',
#   '1층',
#   '층',
#   '매장',
#   '푸드',
#   '푸드코트',
#   '코트',
#   '내',
#   '계란',
#   '계란찜정식',
#   '찜',
#   '정식',
#   '처음',
#   '봣',
#   '사진',
#   '치즈',
#   '계란찜',
#   '메인',
#   '위',
#   '맛',
#   '재미',
#   '성비',
#   '차',
#   '곳',
#   '전주',
#   '전주비빔밥',
#   '비빔밥',
#   '향남지구'],
#  '20': ['서천동'],
#  '21': ['까페', '플라워', '플라워카페', '카페', '신건지동'],
#  '22': ['방배동'],
#  '23': ['내손동'],
#  '24': ['샌드위치', '연어', '연어샌드위치', '사당'],
#  '25': ['핸드', '핸드드립', '드립', '카페', '가로수길'],
#  '26': ['율동'],
#  '27': ['사동'],
#  '28': ['처인구'],
#  '29': ['한남동'],
#  '30': ['고기', '고기집', '집', '화성남양'],
#  '31': ['약대동'],
#  '32': ['얼', '얼그레이', '그레이', '카페', '한남동'],
#  '33': ['물', '물회', '회', '덕성여대'],
#  '34': ['노원동3가'],
#  '35': ['노원동3가'],
#  '36': ['비산동'],
#  '37': ['전',
#   '여기',
#   '5',
#   '5년전',
#   '년',
#   '그때',
#   '기억',
#   '별',
#   '단체',
#   '단체손님',
#   '손님',
#   '손',
#   '지금',
#   '굴비',
#   '굴비정식',
#   '정식',
#   '영광'],
#  '38': ['구들', '술', '감', '스끼', '회', '양', '조금', '부족', '느낌', '맛', '횟집', '발산역'],
#  '39': ['화목동'],
#  '40': ['대전'],
#  '41': ['사근동'],
#  '42': ['밀크', '밀크티', '티', '카페', '연수동'],
#  '43': ['순천'],
#  '44': ['중화', '중화요리', '요리', '술집', '동성로'],
#  '45': ['소흘읍'],
#  '46': ['닭', '닭강정', '강정', '역곡'],
#  '47': ['칵테일', '술집', '원주'],
#  '48': ['잠실동'],
#  '49': ['청국장',
#   '보약',
#   '계란탕',
#   '미세',
#   '미세먼지',
#   '먼지',
#   '반',
#   '평소',
#   '정도',
#   '백발',
#   '남자',
#   '웃음',
#   '불친절',
#   '사장님',
#   '반전매',
#   '불친절하다',
#   '전매',
#   '하다',
#   '곳',
#   '28',
#   '28년',
#   '년',
#   '영업',
#   '주방',
#   '부인',
#   '요리',
#   '여사장',
#   '자부심',
#   '듯',
#   '달',
#   '달전둘',
#   '전',
#   '둘',
#   '거절',
#   '때',
#   '근처',
#   '사람',
#   '여기',
#   '덕',
#   '4',
#   '4차례방문',
#   '차례',
#   '방문',
#   '지역',
#   '맛',
#   '맛집',
#   '집',
#   '외관',
#   '구심',
#   '켠',
#   '수',
#   '동네',
#   '밥집',
#   '그것',
#   '만큼',
#   '양',
#   '제육',
#   '볶음',
#   '오징어',
#   '배',
#   '진한',
#   '진한청국장',
#   '색',
#   '반찬',
#   '정성',
#   '인원수',
#   '반찬가짓수',
#   '가짓수',
#   '사진',
#   '사진1',
#   '1',
#   '3',
#   '3참조',
#   '참조',
#   '요즘',
#   '구이',
#   '고등어',
#   '가격',
#   '포함',
#   '오늘',
#   '칼국수',
#   '바지락',
#   '바지락국물',
#   '국물',
#   '1인분한',
#   '인',
#   '그릇',
#   '분한',
#   '바지락60개',
#   '60',
#   '개',
#   '애',
#   '결국',
#   'ㅎ',
#   '식당',
#   '진짜',
#   '진짜맛집',
#   '수제비',
#   '방배동',
#   '집',
#   '집밥',
#   '밥',
#   '돌진',
#   '방',
#   '방배',
#   '배',
#   '마을',
#   '회관',
#   '식당',
#   '끼',
#   '나위',
#   '밑반찬',
#   '하나하나',
#   '나',
#   '조리',
#   '느낌',
#   '정도',
#   '버섯',
#   '호박',
#   '볶음',
#   '도라지',
#   '도라지무침',
#   '무침',
#   '겉절이',
#   '모두',
#   '간',
#   '반찬',
#   '제공',
#   '깻잎',
#   '조림',
#   '특유',
#   '향취',
#   '적합',
#   '선',
#   '어디',
#   '수',
#   '시',
#   '생선',
#   '생선구이',
#   '구이',
#   '공급',
#   '재료',
#   '편차',
#   '듯',
#   '계란',
#   '계란찜',
#   '찜',
#   '국물',
#   '국물양',
#   '양',
#   '호오',
#   '편리',
#   '주차',
#   '주방',
#   '주방정리',
#   '정리',
#   '홀',
#   '서빙',
#   '등',
#   '기대',
#   '동네',
#   '삼촌',
#   '방문',
#   '생각',
#   '내가',
#   '테이블',
#   '세팅',
#   '소리',
#   '인사',
#   '각오',
#   '일',
#   '일순위',
#   '순위',
#   '참고',
#   '참고사항',
#   '사항',
#   '손님',
#   '성비',
#   '압도적',
#   '여성',
#   '수제비',
#   '방배동'],
#  '50': ['연희',
#   '연희동의',
#   '동의',
#   '숨',
#   '맛',
#   '맛집',
#   '집',
#   '재료',
#   '양',
#   '버섯',
#   '닭',
#   '닭가슴살',
#   '가슴살',
#   '채소',
#   '샌드위치',
#   '살라미',
#   '햄',
#   '터키',
#   '터키햄',
#   '세가지',
#   '콤비네이션',
#   '콤비네이션샌드위치',
#   '짠맛',
#   '취향',
#   '치즈',
#   '선택',
#   '수',
#   '샌드위치',
#   '터키',
#   '터키샌드위치',
#   '연희동'],
#  '51': ['술집', '두정동'],
#  '52': ['케이크', '검단'],
#  '53': ['국물',
#   '국물닭갈비',
#   '닭',
#   '갈비',
#   '대학교',
#   '근처',
#   '근처라',
#   '라',
#   '가격',
#   '세트',
#   '세트구성',
#   '구성',
#   '학생',
#   '부담',
#   '꺼',
#   '사장님',
#   '부부',
#   '친절',
#   '닭갈비',
#   '자체',
#   '살',
#   '사',
#   '사리종류',
#   '리',
#   '종류',
#   '기본적',
#   '수제비',
#   '떡',
#   '닭',
#   '닭갈비',
#   '갈비',
#   '마산'],
#  '54': ['루프', '루프탑라운지', '탑', '라운지', '칵테일', '전주'],
#  '55': ['퓨', '퓨전포차', '전', '포차', '청라'],
#  '56': ['음식',
#   '별',
#   '3',
#   '3점',
#   '점',
#   '정도',
#   '울대',
#   '맛',
#   '맛집',
#   '집',
#   '차돌',
#   '차돌박',
#   '박',
#   '짬뽕',
#   '함박',
#   '함박스테이크',
#   '스테이크',
#   '울산대'],
#  '57': ['분식', '튀김', '진해'],
#  '58': ['분위기',
#   '수',
#   '있음',
#   '파스타',
#   '맛',
#   '맛있음',
#   '맥주',
#   '굿',
#   '피자',
#   '필',
#   '필라프',
#   '라프',
#   '송내역',
#   '피자',
#   '피자맛집',
#   '맛',
#   '집',
#   '줄',
#   '파스타',
#   '파스타맛집',
#   '모두',
#   '강추',
#   '피자',
#   '필',
#   '필라프',
#   '라프',
#   '송내역'],
#  '59': ['스페인', '고기', '고기집', '집', '해운대'],
#  '61': ['두부', '찌개', '구로디지털단지'],
#  '62': ['수제', '수제버거', '버거', '망원동'],
#  '63': ['칼국수', '탕수육', '표선'],
#  '64': ['정육', '정육식당', '식당', '생고기', '백석동'],
#  '65': ['중앙동4가'],
#  '66': ['수플레', '카페', '양산'],
#  '67': ['마카롱', '광주'],
#  '68': ['매장',
#   '주문',
#   '동시',
#   '음식',
#   '음식셋팅',
#   '셋',
#   '팅',
#   '80',
#   '80센티롱',
#   '센티',
#   '롱',
#   '소세지',
#   '철판',
#   '버터',
#   '소리',
#   '후각',
#   '강타',
#   '직원',
#   '직원분',
#   '분',
#   '반',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '주신',
#   '무엇',
#   '라면',
#   '공기',
#   '공기밥',
#   '밥',
#   '1',
#   '1인1메뉴',
#   '인',
#   '메뉴',
#   '무한',
#   '무한제공',
#   '제공',
#   '저녁',
#   '저녁식사',
#   '식사',
#   '수',
#   '수제',
#   '수제소세지',
#   '소세지',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '화정',
#   '국물',
#   '햄',
#   '소시지',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '집',
#   '수제',
#   '수제소세지',
#   '소세지',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '화정',
#   '부대',
#   '부대찌개셋팅',
#   '찌개셋팅',
#   '양도',
#   '동료',
#   '점심',
#   '끼',
#   '거',
#   '계란',
#   '계란후라이',
#   '후라이',
#   '라면',
#   '라면사리',
#   '사리',
#   '무제한',
#   '수',
#   '눈치',
#   '눈치안보',
#   '안보',
#   '수제',
#   '수제소세지',
#   '소세지',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '화정'],
#  '69': ['참치', '갈비', '장항동'],
#  '70': ['꼬들', '꼬들살', '살', '특수', '특수부위', '부위', '풍동'],
#  '71': ['커피', '매호동'],
#  '72': ['화도읍'],
#  '73': ['신곡동'],
#  '74': ['하', '하모샤브샤브', '모샤브', '샤브', '바다', '바다장어', '장어', '월곡동'],
#  '75': ['순대', '순대국밥', '국밥', '청송'],
#  '76': ['촌닭', '치킨', '도안'],
#  '77': ['가격',
#   '국물',
#   '맑은',
#   '맑은국물',
#   '돼지',
#   '돼지라멘',
#   '라멘',
#   '뒤',
#   '가스',
#   '가스오',
#   '오',
#   '생',
#   '예',
#   '라멘',
#   '수제',
#   '수제버거',
#   '버거',
#   '천안',
#   '육수',
#   '가게',
#   '자가',
#   '자가제면',
#   '제면',
#   '제가',
#   '라멘',
#   '여기저기',
#   '09',
#   '09학번식당',
#   '학번',
#   '식당',
#   '라멘',
#   '수제',
#   '수제버거',
#   '버거',
#   '천안'],
#  '78': ['경안동'],
#  '79': ['도봉동'],
#  '80': ['하남읍'],
#  '81': ['신월동'],
#  '82': ['고기', '고기집', '집', '단구동'],
#  '83': ['김해시'],
#  '84': ['길동'],
#  '85': ['닭', '닭갈비', '갈비', '가평'],
#  '86': ['역대',
#   '서비스',
#   '서비스중',
#   '중',
#   '최악',
#   '닭',
#   '닭갈비',
#   '갈비',
#   '분',
#   '옷',
#   '기분',
#   '빳',
#   '빳지맛',
#   '지',
#   '맛',
#   '사람',
#   '실수',
#   '수',
#   '조금',
#   '조심',
#   '주세',
#   '라',
#   '대답',
#   '앞치마',
#   '순간',
#   '내',
#   '내귀',
#   '귀',
#   '의심',
#   '이상',
#   '감',
#   '불안',
#   '역시나',
#   '이번',
#   '소스',
#   '내',
#   '눈',
#   '튀김',
#   '정',
#   '안경',
#   '썻',
#   '정말',
#   '황',
#   '어이',
#   '말',
#   '정신',
#   '사장',
#   '부름',
#   '자초지종',
#   '명함',
#   '직원',
#   '사과',
#   '이제',
#   '됫죠',
#   '영업',
#   '영업방해',
#   '방해',
#   '진상',
#   '진상손님취급',
#   '손님',
#   '취급',
#   '수준',
#   '나물',
#   '밥',
#   '내생',
#   '음식점',
#   '닭',
#   '닭갈비',
#   '갈비',
#   '닭내장',
#   '내장',
#   '춘천',
#   '맛',
#   '양',
#   '기가',
#   '식사',
#   '식사시간',
#   '시간',
#   '자리',
#   '경우',
#   '춘천',
#   '현지인',
#   '추천',
#   '닭',
#   '닭갈비집',
#   '갈비집',
#   '점',
#   '에어컨',
#   '닭',
#   '닭갈비',
#   '갈비',
#   '닭내장',
#   '내장',
#   '춘천',
#   '맛',
#   '가격',
#   '춘천',
#   '한번',
#   '집',
#   '닭',
#   '닭갈비',
#   '갈비',
#   '닭내장',
#   '내장',
#   '춘천',
#   '닭',
#   '닭갈비',
#   '갈비',
#   '춘천',
#   '1.5',
#   '1',
#   '1인분',
#   '인분',
#   '주문',
#   '분',
#   '1.5닭갈비',
#   '소문',
#   '10',
#   '10년',
#   '년',
#   '듯',
#   '하다',
#   '전',
#   '급',
#   '먹자',
#   '가족',
#   '춘천택시기사님',
#   '택시',
#   '기사',
#   '기사님',
#   '님',
#   '날',
#   '기억',
#   '서울',
#   '은',
#   '양',
#   '맛',
#   '유명',
#   '닭갈비골목',
#   '골목',
#   '이곳저곳',
#   '생각',
#   '주관적',
#   '무엇',
#   '닭내장',
#   '내장',
#   '가게',
#   '닭내장때문',
#   '때문',
#   '라도',
#   '닭',
#   '닭갈비',
#   '갈비',
#   '닭내장',
#   '내장',
#   '춘천',
#   '카레',
#   '카레맛',
#   '맛',
#   '특색',
#   '느낌',
#   '찬',
#   '마늘',
#   '양파',
#   '상추',
#   '추운',
#   '날씨',
#   '방문해으',
#   '히터',
#   '가동',
#   '직원',
#   '서빙',
#   '약간',
#   '츤',
#   '츤데레',
#   '데',
#   '레',
#   '주차',
#   '11',
#   '11시30분',
#   '시',
#   '30',
#   '분',
#   '13',
#   '13시30분',
#   '시',
#   '분',
#   '사이',
#   '가게',
#   '앞',
#   '주차가능',
#   '가능',
#   '나머지',
#   '시간',
#   '단속',
#   '주차장',
#   '닭',
#   '닭갈비',
#   '갈비',
#   '닭내장',
#   '내장',
#   '춘천'],
#  '87': ['닭', '닭갈비', '갈비', '김해시'],
#  '88': ['북', '북카페', '카페', '양재천'],
#  '89': ['한옥', '한옥카페', '카페', '삼청동'],
#  '90': ['파스타', '잠원동'],
#  '91': ['카페', '규모', '야외', '옥상', '루프', '루프탑', '탑', '카페', '브런', '삼송'],
#  '92': ['예전', '자주', '곳', '어디', '때', '제일', '꼬르소꼬', '자리', '음식', '브런', '청담'],
#  '93': ['파스타', '남문'],
#  '94': ['계단',
#   '위험',
#   'ㅜ',
#   '자리',
#   '생각',
#   '올',
#   '화이트',
#   '카페',
#   '카페운영',
#   '운영',
#   '분',
#   '열정',
#   '수플레',
#   '카페',
#   '대흥',
#   '자랑',
#   '테이블',
#   '불편',
#   '팬',
#   '팬케이크',
#   '케이크',
#   '음료',
#   '수플레',
#   '카페',
#   '대흥'],
#  '95': ['카페', '운양동'],
#  '96': ['소주방', '소주', '다대포'],
#  '97': ['원성동'],
#  '98': ['일산'],
#  '99': ['디저트', '디저트카페', '카페', '담양'],
#  '100': ['율정동'],
#  '101': ['괴안동'],
#  '102': ['평소',
#   '당근',
#   '당근케이크',
#   '케이크',
#   '위',
#   '모형',
#   '줄',
#   '실제',
#   '음료',
#   '몸',
#   '건강',
#   '느낌',
#   '베이비',
#   '브런',
#   '서귀포'],
#  '103': ['평거동'],
#  '104': ['돼지', '돼지갈비', '갈비', '임계면'],
#  '105': ['고기', '고기집', '집', '화로', '화로구이', '구이', '진주'],
#  '106': ['천호동'],
#  '107': ['소사동'],
#  '108': ['마평동'],
#  '109': ['돼지', '돼지갈비', '갈비', '수유'],
#  '110': ['설렁탕', '집', '만두', '사이드', '메뉴', '설렁탕', '돼지', '돼지갈비', '갈비', '삼선교'],
#  '111': ['해', '해물탕', '물탕', '해물', '해물찜', '찜', '둔촌동'],
#  '112': ['삼겹살', '흑', '흑돼지', '돼지', '제주'],
#  '113': ['순두부', '두부', '강릉'],
#  '114': ['한우', '등심', '강남구청역'],
#  '115': ['황태', '처인구'],
#  '116': ['카페', '커피', '삼산'],
#  '117': ['돼지', '돼지국밥', '국밥', '순대', '중방동'],
#  '118': ['해물', '해물뚝배기', '뚝배기', '안동'],
#  '119': ['연탄', '연탄불고기', '불고기', '동탄'],
#  '120': ['연탄', '연탄불고기', '불고기', '신당동'],
#  '121': ['연탄', '연탄불고기', '불고기', '고추장', '고추장불고기', '공릉동'],
#  '122': ['장성'],
#  '123': ['커피', '로제', '로제파스타', '파스타', '에그베네딕트', '샐러드', '분위기', '브런', '카페', '강릉'],
#  '124': ['석대동'],
#  '125': ['곱창', '막창', '정왕동'],
#  '126': ['심곡동'],
#  '127': ['화성시'],
#  '128': ['연산9동'],
#  '129': ['강서',
#   '강서구',
#   '구',
#   '맛',
#   '맛집',
#   '집',
#   '배달',
#   '1',
#   '1시간기본',
#   '시간',
#   '기본',
#   '픽업',
#   '추천',
#   '야채',
#   '야채곱창',
#   '곱창',
#   '거기',
#   '소스',
#   '진짜',
#   '중독성',
#   '치즈',
#   '치즈곱창',
#   '곱창',
#   '강서구청'],
#  '130': ['곱창', '치즈', '치즈곱창', '김포'],
#  '131': ['맛',
#   '가격',
#   '무',
#   '나',
#   '족발',
#   '족발집',
#   '집',
#   '반',
#   '반반족발',
#   '불',
#   '불족발',
#   '일반',
#   '일반족발',
#   '주문',
#   '셋',
#   '반주',
#   '양',
#   '보쌈',
#   '메뉴',
#   '사당',
#   '이곳',
#   '특색',
#   '거',
#   '족발',
#   '보쌈',
#   '사당역'],
#  '132': ['족발', '첨단'],
#  '133': ['고기',
#   '맛',
#   '점',
#   '가게',
#   '거',
#   '족발',
#   '쟁반',
#   '쟁반국수',
#   '국수',
#   '신창',
#   '맛',
#   '광산',
#   '광산구',
#   '광산구쪽',
#   '구',
#   '쪽',
#   '곳',
#   '맛집',
#   '집',
#   '유명',
#   '위생적',
#   '여',
#   '믿음',
#   '얼마',
#   '얼마전',
#   '전',
#   '방문',
#   '방문때',
#   '때',
#   '부대',
#   '술',
#   '족발',
#   '족발집',
#   '완전',
#   '짱',
#   '족발',
#   '쟁반',
#   '쟁반국수',
#   '국수',
#   '신창'],
#  '134': ['꼼장어', '가격', '재료', '신선', '수', '산', '산꼼장어', '꼼장어', '한성대'],
#  '135': ['어방동'],
#  '136': ['독곡동'],
#  '137': ['뒷', '뒷고기', '고기', '한우', '연향동'],
#  '138': ['명일동'],
#  '139': ['제주',
#   '제주도',
#   '도',
#   '월',
#   '월정리',
#   '정리',
#   '해변',
#   '근처',
#   '카페',
#   '콧수염',
#   '옆',
#   '위치',
#   '선물',
#   '구좌'],
#  '141': ['떡갈비', '잔치', '잔치국수', '국수', '일산'],
#  '142': ['nan'],
#  '143': ['파스타', '피자', '봉선동'],
#  '144': ['카페', '봉곡동'],
#  '145': ['압량면'],
#  '146': ['전복', '수완지구'],
#  '147': ['파스타', '피자', '함덕'],
#  '148': ['수지',
#   '롯데',
#   '롯데몰',
#   '몰',
#   '4',
#   '4층',
#   '층',
#   '돈까스',
#   '돈까스체인점',
#   '체인점',
#   '고추',
#   '거',
#   '예전',
#   '지점',
#   '기억',
#   '뚝배기',
#   '떡볶이',
#   '모듬',
#   '모듬정식',
#   '정식',
#   '함박',
#   '함박스테이크',
#   '스테이크',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '용인수지',
#   '유명',
#   '맛',
#   '맛집이',
#   '집이',
#   '수지',
#   '수지롯데몰',
#   '롯데',
#   '몰',
#   '입',
#   '방문',
#   '기본',
#   '대기',
#   '대기시간',
#   '시간',
#   '60',
#   '60분정도',
#   '분',
#   '정도',
#   '기대',
#   '메뉴',
#   '주문',
#   '소감',
#   '쏘쏘입니',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '식',
#   '식감',
#   '감',
#   '소스',
#   '소스양이',
#   '양이',
#   '추가',
#   '남산',
#   '생각',
#   '치즈',
#   '치즈돈까스',
#   '일반적',
#   '점수',
#   '수',
#   '이유',
#   '함박',
#   '냉동',
#   '냉동함박',
#   '기성품',
#   '떡갈비',
#   '거',
#   '최악',
#   '테이블',
#   '다',
#   '건',
#   '득',
#   '느낌',
#   '정식',
#   '유명맛집들이',
#   '집들이',
#   '가맹',
#   '퀄리티',
#   '가격',
#   '외식',
#   '외식산업',
#   '산업',
#   '퇴보',
#   '걱정',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '용인수지'],
#  '149': ['차',
#   '곳',
#   '여자',
#   '둘',
#   '모듬',
#   '모듬정식',
#   '정식',
#   '옛날',
#   '돈가스',
#   '살',
#   '튀김',
#   '생각',
#   '수',
#   '셀프',
#   '메뉴',
#   '고추',
#   '쌈',
#   '쌈장',
#   '장',
#   '단무지',
#   '등',
#   '때문',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '남산',
#   '웨이팅',
#   '줄',
#   '길',
#   '만',
#   '2',
#   '2층',
#   '층',
#   '처음',
#   '1',
#   '1층',
#   '스프',
#   '김치',
#   '단무지',
#   '고추',
#   '셀프',
#   '구',
#   '돈까스',
#   '소스',
#   '맛',
#   '튀김',
#   '고기',
#   '함박',
#   '함박스테이크',
#   '스테이크',
#   '왕',
#   '왕돈까스',
#   '양이',
#   '적지',
#   '시간적',
#   '여유',
#   '곳',
#   '발',
#   '발렛',
#   '렛',
#   '아저씨',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '남산',
#   '남산',
#   '유명',
#   '돈까스',
#   '돈까스집',
#   '집',
#   '도전',
#   '우',
#   '우결',
#   '결',
#   '등',
#   '프로그램',
#   '촬영',
#   '촬영지로',
#   '지로',
#   '곳',
#   '맛',
#   '보통',
#   '수준',
#   '관광지',
#   '사람',
#   '짐',
#   '주차',
#   '안내',
#   '분',
#   '해',
#   '해주심',
#   '주심',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '남산',
#   '돈',
#   '돈가스',
#   '가스',
#   '집',
#   '호객',
#   '분',
#   '주차',
#   '방송',
#   '전문',
#   '전문식당',
#   '식당',
#   '생각',
#   '피자',
#   '파스타',
#   '샐러드',
#   '등',
#   '음식',
#   '음식종류',
#   '종류',
#   '다양',
#   '세트',
#   '메뉴',
#   '구성',
#   '위주',
#   '메인',
#   '식전',
#   '빵',
#   '특이',
#   '양',
#   '맛',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '남산',
#   '모듬',
#   '모듬정식',
#   '정식',
#   '구성',
#   '맛',
#   '취향',
#   '듯',
#   '주차',
#   '아저씨',
#   '친절',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '남산',
#   '모듬',
#   '모듬까스',
#   '까스',
#   '때',
#   '떡',
#   '떡돈',
#   '돈',
#   '수',
#   '저',
#   '줄',
#   '다',
#   '조합',
#   '구영',
#   '추천',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '남산',
#   '예전',
#   '맛',
#   '모닝',
#   '모닝빵',
#   '빵',
#   '마카로니',
#   '청양',
#   '청양고추',
#   '고추',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '남산',
#   '남산',
#   '돈까스',
#   '돈까스집',
#   '집',
#   '중',
#   '최근',
#   '매스컴',
#   '곳',
#   '101',
#   '101번째',
#   '번째',
#   '식당',
#   '식당평가',
#   '평가',
#   '상호',
#   '런',
#   '때문',
#   '나',
#   '소스',
#   '한국식',
#   '왕',
#   '왕돈까스',
#   '타르타르',
#   '타르타르소스',
#   '생선',
#   '생선까스',
#   '까스',
#   '오이',
#   '오이고추',
#   '고추',
#   '궁합',
#   '듯이',
#   '때',
#   '일본식',
#   '명동',
#   '명동돈까스',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '남산',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '남산',
#   '회전',
#   '편',
#   '줄',
#   '돈까스',
#   '돈까스맛',
#   '맛',
#   '직원',
#   '서비스',
#   '마인드',
#   '제로',
#   '제로임',
#   '임',
#   '아줌마',
#   '아줌마직원',
#   '명이',
#   '말',
#   '둥',
#   '대꾸',
#   '표정',
#   '이벤트',
#   '업',
#   '업로드',
#   '로드',
#   '후',
#   '선',
#   '이벤트서비스',
#   '음료',
#   '대체적',
#   '손님',
#   '태도',
#   '쉣',
#   '도',
#   '짐',
#   '돈',
#   '시간',
#   '움',
#   '카운터',
#   '남자',
#   '친절',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '남산'],
#  '150': ['거',
#   '고구마',
#   '고구마치즈',
#   '치즈',
#   '계속',
#   '먹',
#   '스프',
#   '돈까스',
#   '센트럴시티',
#   '튀김옷',
#   '뚝배기',
#   '떡볶이',
#   '돈까스',
#   '경우',
#   '소스',
#   '만족',
#   '캡',
#   '캡사이신이',
#   '사이',
#   '신이',
#   '위',
#   '기름',
#   '눈',
#   '건',
#   '수',
#   '생각',
#   '플레이팅',
#   '스타일',
#   '고전적',
#   '추억',
#   '곱',
#   '가격',
#   '그',
#   '서비스',
#   '수프',
#   '장국',
#   '고추',
#   '플레이',
#   '플레이팅',
#   '팅',
#   '등',
#   '년대',
#   '분위기',
#   '만원',
#   '이상',
#   '이상대',
#   '대',
#   '동결',
#   '9',
#   '9천원',
#   '천',
#   '원',
#   '정도',
#   '터',
#   '돈까스',
#   '센트럴시티',
#   '주변',
#   '기대',
#   '본점',
#   '돈까스',
#   '센트럴시티'],
#  '151': ['갤러리',
#   '백화점',
#   '지하',
#   '돈까스',
#   '돈까스집',
#   '집',
#   '메뉴',
#   '다양',
#   '맛',
#   '돈까스',
#   '수원',
#   '수원',
#   '갤러리',
#   '지하',
#   '푸드',
#   '푸드코트',
#   '코트',
#   '양도',
#   '맛',
#   '맛있음',
#   '있음',
#   '미니',
#   '미니돈까스',
#   '돈까스',
#   '돈가스',
#   '돈까스',
#   '수원'],
#  '152': ['재',
#   '재방',
#   '방',
#   '70',
#   '비계',
#   '내',
#   '운',
#   '지도',
#   '최소',
#   '4',
#   '4번',
#   '번',
#   '맥주',
#   '맥주컵',
#   '컵',
#   '위생',
#   '위생관리',
#   '관리',
#   '의심',
#   '먼지',
#   '먼지맛',
#   '맛',
#   '마',
#   '수세미',
#   '소독',
#   '소독문제',
#   '문제',
#   '확률',
#   '생각',
#   '비판',
#   '거',
#   '장점',
#   '개',
#   '소스',
#   '은근',
#   '매력적',
#   '약간',
#   '땅콩',
#   '땅콩잼',
#   '잼',
#   '메리트',
#   '스프',
#   '돈까스',
#   '관련',
#   '메뉴',
#   '선택',
#   '폭',
#   '백화점',
#   '기분',
#   '수',
#   '만큼',
#   '돈까스',
#   '인사동'],
#  '153': ['치즈', '치즈돈까스', '돈까스', '천호동'],
#  '154': ['치즈',
#   '치즈돈까스',
#   '돈까스',
#   '소스',
#   '콩나물',
#   '가격',
#   'ㅎ',
#   'ㄷ',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '가산디지털단지',
#   '친절',
#   '친절보통',
#   '보통',
#   '음식',
#   '맛',
#   '소스',
#   '생',
#   '생강향',
#   '강',
#   '향',
#   '분식집',
#   '맛대비',
#   '대비',
#   '가격',
#   '왕',
#   '왕돈까스',
#   '돈까스',
#   '가산디지털단지'],
#  '155': ['돈까스', '왕', '왕돈까스', '명동'],
#  '156': ['왕', '왕돈까스', '돈까스', '가든파이브'],
#  '157': ['치즈', '치즈퐁듀', '퐁듀', '닭', '닭갈비', '갈비', '가평'],
#  '158': ['스테이크', '파스타', '양재동'],
#  '159': ['스튜', '카페', '응암동'],
#  '160': ['카페', '도곡'],
#  '161': ['가락동'],
#  '162': ['커피', '인계동'],
#  '163': ['논현동'],
#  '164': ['카페', '약수'],
#  '165': ['제육', '제육쌈밥', '쌈', '밥', '쌈밥', '청계산'],
#  '166': ['붕어빵', '아이스', '아이스크림', '크림', '속초관광수산시장'],
#  '167': ['전농동'],
#  '168': ['커피', '서초동'],
#  '169': ['마장면'],
#  '170': ['수제', '수제버거', '버거', '버팔로', '버팔로윙', '윙', '홍대'],
#  '171': ['피자', '치킨', '파주'],
#  '172': ['하동'],
#  '173': ['분위기',
#   '허',
#   '안주',
#   '알콜',
#   '주점',
#   '사',
#   '술집',
#   '연남동',
#   '연',
#   '연트럴파크',
#   '트럴',
#   '파크',
#   '곳',
#   '나름',
#   '분위기',
#   '느낌',
#   '내부',
#   '편',
#   '소주',
#   '소주칵테일',
#   '칵테일',
#   '때',
#   '맛',
#   '과육',
#   '연남',
#   '연남동',
#   '동',
#   '가격',
#   '술집',
#   '안',
#   '안주가',
#   '주가',
#   '파스타',
#   '있어서',
#   '술',
#   '저녁',
#   '가능',
#   '거',
#   '사',
#   '술집',
#   '연남동'],
#  '174': ['카페', '수원'],
#  '175': ['탕수육',
#   '거',
#   '짬뽕',
#   '야채',
#   '조금',
#   '터',
#   '정도',
#   '둘',
#   '맛',
#   '짬뽕',
#   '짬뽕밥',
#   '밥',
#   '김해'],
#  '176': ['수제햄', '부대', '부대찌개', '찌개', '동탄'],
#  '177': ['1023',
#   '1023양과점',
#   '양',
#   '과점',
#   '곳',
#   '군자',
#   '군자점',
#   '점',
#   '마카롱',
#   '판매',
#   '송',
#   '송파점',
#   '파',
#   '클래스',
#   '위주',
#   '진행',
#   '예약',
#   '예약판매',
#   '얼',
#   '얼그레이마카롱',
#   '그레이',
#   '얼그레이',
#   '맛',
#   '마카롱',
#   '커피',
#   '송파역'],
#  '178': ['마카롱', '홍차', '군자'],
#  '179': ['리코', '치즈', '한식', '이태원'],
#  '180': ['음식',
#   '회전율',
#   '편',
#   '데이트',
#   '재',
#   '재방문의사있음',
#   '방문',
#   '의사',
#   '있음',
#   '수플레',
#   '레스토랑',
#   '역삼동'],
#  '181': ['빵집', '화곡역'],
#  '182': ['닭', '닭갈비', '갈비', '울산'],
#  '183': ['카페', '삼척'],
#  '184': ['카레', '떡볶이', '커피', '곳', '브런치', '먹', '해', '카페', '커피', '향남'],
#  '185': ['카페', '고대'],
#  '186': ['비산동'],
#  '187': ['카페', '향남'],
#  '188': ['카페', '가평'],
#  '189': ['농서동'],
#  '190': ['당근', '당근케이크', '케이크', '카페', '묵호진동'],
#  '191': ['마카롱', '목포'],
#  '192': ['라', '라떼', '떼', '커피', '안산'],
#  '193': ['단체', '단체도시락', '도시락', '경주'],
#  '194': ['소주', '술집', '다사'],
#  '195': ['라멘', '돈', '돈코츠라멘', '코', '츠', '하양'],
#  '196': ['라멘', '돈', '돈코츠라멘', '코', '츠', '산격동'],
#  '197': ['자극적', '맛', '아이', '가기', '곳', '파스타', '이매'],
#  '198': ['부대', '부대찌개', '찌개', '세종대'],
#  '199': ['조원동'],
#  '200': ['토스트', '월촌역'],
#  '201': ['카페', '구미'],
#  '202': ['카페', '경남대'],
#  '203': ['맥주', '일산'],
#  '204': ['건건동'],
#  '205': ['홍제동'],
#  '206': ['고기',
#   '주문',
#   '계란',
#   '계란찜',
#   '찜',
#   '기본',
#   '기본서비스',
#   '서비스',
#   '삼겹살',
#   '고기',
#   '고기집',
#   '집',
#   '탄현'],
#  '207': ['아구', '아구찜', '찜', '해물', '해물찜', '일산'],
#  '208': ['팔달문'],
#  '209': ['철판', '닭', '닭갈비', '갈비', '이충동'],
#  '210': ['당하동'],
#  '211': ['부대', '부대찌개', '찌개', '생고기', '군자역'],
#  '212': ['문어', '문어짬뽕', '짬뽕', '울산'],
#  '213': ['통', '통목살', '목살', '짬뽕', '남포동'],
#  '214': ['석수동'],
#  '215': ['송학동'],
#  '216': ['바다',
#   '경치',
#   '그리스',
#   '카페',
#   '강화도',
#   '커피나',
#   '와플',
#   '와플종류',
#   '종류',
#   '식사',
#   '녁',
#   '노을',
#   '바람',
#   '그리스',
#   '카페',
#   '강화도',
#   '노을',
#   '차',
#   '수',
#   '곳',
#   '계절',
#   '해',
#   '생맥주',
#   '판매',
#   '한잔',
#   '그리스',
#   '카페',
#   '강화도',
#   '음식',
#   '양은',
#   '커피',
#   '맛',
#   '중상',
#   '중상정도',
#   '정도',
#   '민트',
#   '코',
#   '프라푸치노',
#   '한데',
#   '사진',
#   '여자',
#   '여자친구',
#   '친구',
#   '화장실',
#   '별로래',
#   '별',
#   '별점',
#   '점',
#   '그리스',
#   '카페',
#   '강화도'],
#  '217': ['회덕동'],
#  '218': ['군산'],
#  '219': ['돈',
#   '돈아가',
#   '아가',
#   '곳',
#   '엿',
#   '언니',
#   '샌드위치',
#   '집',
#   '도전',
#   '거',
#   '음료',
#   '이',
#   '이가격',
#   '가격',
#   '팔',
#   '충격',
#   'ㅜ',
#   '아이스',
#   '아이스바',
#   '바',
#   '카페',
#   '여의도',
#   '콘래드',
#   '1',
#   '1층',
#   '층',
#   '금',
#   '분위기',
#   '가격',
#   '가격대',
#   '대',
#   '일반',
#   '프렌',
#   '프렌차이즈',
#   '차',
#   '이즈',
#   '커피숍',
#   '차이',
#   '여의도',
#   '커피',
#   '곳',
#   '추천',
#   '아이스',
#   '아이스바',
#   '바',
#   '카페',
#   '여의도'],
#  '220': ['카페', '브라', '전북대'],
#  '221': ['송',
#   '송파나루역',
#   '파',
#   '나루',
#   '역',
#   '술집',
#   '맛',
#   '맛집',
#   '집',
#   '안',
#   '안주가',
#   '주가',
#   '최',
#   '최애',
#   '애',
#   '방이',
#   '방이동',
#   '동',
#   '집주변',
#   '주변',
#   '동네',
#   '동네주민',
#   '주민',
#   '추천',
#   '방문',
#   '한번',
#   '뒤',
#   '안주',
#   '실패',
#   '적',
#   '오픈',
#   '주방',
#   '요리',
#   '사장님',
#   '친절',
#   '공간',
#   '테이블',
#   '3',
#   '3개',
#   '개',
#   '바',
#   '바테이블',
#   '편',
#   '화장실',
#   '송리',
#   '길',
#   '길쪽',
#   '쪽',
#   '낮',
#   '카페',
#   '데이트',
#   '저녁',
#   '술',
#   '가기',
#   'ㄹ',
#   'ㄹㅇ',
#   'ㅇ',
#   '안주맛집',
#   '이자',
#   '유린',
#   '송파나루역',
#   '음식',
#   '무엇',
#   '사장님',
#   '친절',
#   '거',
#   '터',
#   '쵝',
#   '쵝오',
#   '오',
#   '이자',
#   '유린',
#   '송파나루역',
#   '사장님',
#   '친절',
#   '음식',
#   '양도',
#   '끝',
#   '딩',
#   '생맥주',
#   '최고',
#   '이자',
#   '유린',
#   '송파나루역',
#   '맛',
#   '분위기',
#   '가격',
#   '3',
#   '3가지',
#   '가지',
#   '모두',
#   '장점',
#   '가게',
#   '일주일',
#   '혼',
#   '혼술',
#   '술',
#   '3번',
#   '번',
#   '거',
#   '촌',
#   '촌호수',
#   '호수',
#   '데이트',
#   '최고',
#   '이자',
#   '유린',
#   '송파나루역',
#   '주말',
#   '날',
#   '편',
#   '고',
#   '가벼운',
#   '마음',
#   '지인',
#   '한잔',
#   '때',
#   '거',
#   '집',
#   '집근처',
#   '근처',
#   '술집',
#   '인테리어',
#   '뿐',
#   '맛',
#   '감동적',
#   '이자',
#   '유린',
#   '송파나루역',
#   '가격',
#   '이자',
#   '유린',
#   '송파나루역',
#   '송리',
#   '길',
#   '근처',
#   '위치',
#   '조용하',
#   '술집',
#   '거',
#   '저',
#   '최',
#   '최애',
#   '애',
#   '사장님',
#   '친절',
#   '안주',
#   '생맥주',
#   '생맥주조차',
#   '조',
#   '차',
#   '술집안',
#   '안',
#   '화장실',
#   '지인',
#   '인정',
#   '맛',
#   '맛집',
#   '집',
#   '이자',
#   '유린',
#   '송파나루역',
#   '처음',
#   '때',
#   '집',
#   '음식',
#   '퀄리티',
#   '술집',
#   '안주',
#   '허',
#   '맛',
#   '맛집',
#   '술',
#   '부담',
#   '인테리어',
#   '오픈',
#   '주방',
#   '느낌',
#   '방문',
#   '방문후기',
#   '후기',
#   '내',
#   '최',
#   '최애',
#   '애',
#   '짬뽕',
#   '게살',
#   '게살내장파스타',
#   '내장',
#   '파스타',
#   '이자',
#   '유린',
#   '송파나루역',
#   '음식',
#   '맛',
#   '좋앗어',
#   '이자',
#   '유린',
#   '송파나루역',
#   '내장',
#   '파스타',
#   '존',
#   '존맛탱',
#   '맛',
#   '탱',
#   '사장님',
#   '친절',
#   '가게',
#   '분위기',
#   '이자',
#   '유린',
#   '송파나루역',
#   '음식',
#   '존',
#   '존맛탱구리',
#   '맛',
#   '탱',
#   '구리',
#   '잠실',
#   '잠실새내',
#   '새내',
#   '저희',
#   '신',
#   '신천술집',
#   '천',
#   '술집',
#   '삼전',
#   '12',
#   '12시간',
#   '시간',
#   '일하',
#   '성',
#   '구지',
#   '버스',
#   '타고',
#   '회식',
#   '여',
#   '이유',
#   '말',
#   '안해',
#   '아시',
#   '아시겠졀',
#   '겠졀',
#   '사장님',
#   '핵',
#   '핵인',
#   '인',
#   '라',
#   '음악',
#   '저번',
#   '남',
#   '밖',
#   '육',
#   '문자',
#   '소리',
#   '안',
#   '거',
#   '술',
#   '정도',
#   '적합',
#   '음량',
#   '주심',
#   '조',
#   '화장실',
#   '지하철',
#   '냄새',
#   '청결',
#   '노래',
#   '노래소리때매',
#   '때',
#   '매',
#   '쉬',
#   '쉬소리',
#   '연',
#   '개꿀',
#   '개꿀딱스',
#   '딱스',
#   '성비',
#   '기본',
#   '기본세팅',
#   '세팅',
#   '코',
#   '사비',
#   '모',
#   '모찌리',
#   '찌',
#   '리',
#   '후',
#   '해물',
#   '해물짬뽕',
#   '짬뽕',
#   '게살',
#   '게살내장파스타',
#   '내장',
#   '파스타',
#   '밥',
#   '가요',
#   '진짜',
#   '개',
#   '개코',
#   '비린내',
#   '절대',
#   '사비지려',
#   '지려',
#   '넘',
#   '넘췬절해연',
#   '췬',
#   '절해',
#   '모든',
#   '귀와',
#   '눈',
#   '젓가락',
#   '쏘스',
#   '쏘스윗',
#   '윗',
#   '술게임',
#   '게임',
#   '일',
#   '나리',
#   '숩',
#   '안주',
#   '집이',
#   '용',
#   '갑',
#   '재료',
#   '손질',
#   '해놓으샤',
#   '피쓰',
#   '직원',
#   '직원동생',
#   '동생',
#   '사진',
#   '이자',
#   '유린',
#   '송파나루역',
#   '분위기',
#   '이자',
#   '동생',
#   '추천',
#   '핵',
#   '짬뽕',
#   '모',
#   '모찌리',
#   '찌',
#   '리',
#   '후도',
#   '완전',
#   '찹쌀',
#   '이자',
#   '유린',
#   '송파나루역'],
#  '222': ['카페', '명동'],
#  '223': ['가게',
#   '불편',
#   '고기',
#   '양',
#   '모듬',
#   '둘',
#   '부족',
#   '수준',
#   '볶음밥',
#   '막창',
#   '삼겹살',
#   '뒷',
#   '뒷더미살',
#   '더미',
#   '살',
#   '아구',
#   '식',
#   '식감이',
#   '감이',
#   '특이',
#   '맛',
#   '막창',
#   '아구',
#   '종로'],
#  '224': ['부대', '부대찌개', '찌개', '불당동'],
#  '225': ['관고동'],
#  '226': ['부대', '부대찌개', '찌개', '부천'],
#  '227': ['부대', '부대찌개', '찌개', '하남'],
#  '228': ['고',
#   '고깃값',
#   '깃',
#   '값',
#   '소주',
#   '소주값',
#   '1500',
#   '1500원',
#   '원',
#   '완전',
#   '완전최고',
#   '최고',
#   '가성',
#   '가성비도',
#   '비도',
#   '맛',
#   '곳',
#   '모듬',
#   '모듬세트1',
#   '세트',
#   '1',
#   '48000',
#   '48000원',
#   '등',
#   '등심',
#   '심',
#   '토시',
#   '토시살',
#   '살',
#   '갈비',
#   '갈비살',
#   '2',
#   '2부위',
#   '부위',
#   '선택도',
#   '가능',
#   '앞',
#   '고기',
#   '질',
#   '진',
#   '생각',
#   '양념',
#   '돼지',
#   '돼지갈비',
#   '소스',
#   '양배추',
#   '대부분',
#   '칸막이',
#   '혼자',
#   '손님',
#   '가기',
#   '사진',
#   '냉면',
#   '물',
#   '물냉비냉',
#   '냉비',
#   '냉',
#   '찌개',
#   '소고기',
#   '화성'],
#  '229': ['동호동'],
#  '230': ['동면'],
#  '231': ['비산동'],
#  '232': ['술집', '밥집', '경성대'],
#  '233': ['원미본동'],
#  '234': ['금광동'],
#  '235': ['디저트', '디저트카페', '카페', '삼덕동'],
#  '236': ['오', '오마카세', '마', '카', '세', '사', '서촌'],
#  '237': ['카페', '별내'],
#  '238': ['한우', '서울'],
#  '239': ['생과일',
#   '생과일주스',
#   '주스',
#   '종류',
#   '분위기',
#   '카페',
#   '커피',
#   '왕십리',
#   '캐주얼',
#   '분위기',
#   '다양',
#   '소품',
#   '눈길',
#   '카페',
#   '시기',
#   '테라스',
#   '테라스부분',
#   '부분',
#   '확장',
#   '사용',
#   '전반적',
#   '친구',
#   '집',
#   '커피맛',
#   '물맛',
#   '고소',
#   '특유',
#   '커피',
#   '커피향',
#   '향',
#   '에스프레소',
#   '샷',
#   '물',
#   '생각',
#   '와플',
#   '가격',
#   '가격대비',
#   '대비',
#   '퀄리티',
#   '생과일',
#   '주스',
#   '종류',
#   '과일',
#   '과일주스',
#   '분',
#   '선호',
#   '화장실',
#   '옆',
#   '건물',
#   '남녀',
#   '남녀공용',
#   '공용',
#   '저녁',
#   '저녁시간',
#   '시간',
#   '정돈',
#   '카페',
#   '커피',
#   '왕십리',
#   '곳',
#   '약간',
#   '포스',
#   '분',
#   '출몰',
#   '이유',
#   'ㄷ',
#   '가게',
#   '분위기',
#   '특별',
#   '점',
#   '저',
#   '마디',
#   '무',
#   '나',
#   '카페',
#   '커피',
#   '왕십리'],
#  '240': ['파스타', '피자', '망원동'],
#  '241': ['nan'],
#  '242': ['펍', '종로'],
#  '244': ['돈까스', '여수'],
#  '245': ['파스타', '돈까스', '장성'],
#  '246': ['카페', '향남'],
#  '247': ['양', '양꼬치', '꼬치', '대림역'],
#  '248': ['맛',
#   '다만',
#   '때',
#   '회전율',
#   '함박',
#   '함박스테이크',
#   '스테이크',
#   '명란',
#   '명란파스타',
#   '파스타',
#   '어은동'],
#  '249': ['태전동'],
#  '250': ['포', '포천이동갈비', '천', '이동', '갈비', '카페', '이동면'],
#  '251': ['이태원'],
#  '252': ['갈비', '글', '대전관평동'],
#  '253': ['카페', '커피', '애월'],
#  '254': ['함박', '함박스테이크', '스테이크', '경리단길'],
#  '255': ['죽왕면'],
#  '256': ['풍덕천동'],
#  '257': ['질',
#   '소고기',
#   '직원',
#   '수',
#   '반찬',
#   '매장',
#   '분위기',
#   '고기',
#   '정도',
#   '뒤',
#   '평일',
#   '저녁',
#   '안',
#   '팀',
#   '번',
#   '이해',
#   '어려움',
#   '가격',
#   '데',
#   '테이블',
#   '호출',
#   '벨',
#   '숙성',
#   '우',
#   '한우',
#   '광화문'],
#  '258': ['요리', '요리주점', '주점', '술집', '강남구청역'],
#  '259': ['불고기', '대전관평동'],
#  '260': ['숯불', '숯불갈비', '갈비', '돼지', '돼지갈비', '유성구'],
#  '261': ['카페', '라', '라떼', '떼', '서촌'],
#  '262': ['심곡동'],
#  '263': ['천호동'],
#  '264': ['낙지', '낙지짬뽕', '짬뽕', '족발', '장평동'],
#  '265': ['닭', '닭갈비', '갈비', '춘천'],
#  '266': ['닭', '닭갈비집중', '갈비', '집중', '치즈', '볶음밥', '짱', '닭', '닭갈비', '갈비', '단구동'],
#  '267': ['닭', '닭갈비', '갈비', '제천'],
#  '268': ['닭',
#   '닭발',
#   '발',
#   '예전',
#   '가격',
#   '마약',
#   '마약떡볶이',
#   '떡볶이',
#   '닭',
#   '닭발',
#   '발',
#   '석쇠',
#   '석쇠구이',
#   '구이',
#   '천호동'],
#  '269': ['거여동'],
#  '270': ['전골', '삼겹살', '곡반정동'],
#  '271': ['호계본동'],
#  '272': ['평거동'],
#  '273': ['신동면'],
#  '274': ['북부동'],
#  '275': ['똥집', '닭', '구미'],
#  '276': ['불', '불닭발', '닭', '발', '망정동'],
#  '277': ['nan'],
#  '278': ['생연동'],
#  '279': ['중부동'],
#  '280': ['똥집', '구미'],
#  '281': ['중국집', '역곡'],
#  '282': ['범어동'],
#  '283': ['우만동'],
#  '284': ['오', '오돌', '돌', '주먹밥', '치킨', '장승포동'],
#  '285': ['원종본동'],
#  '286': ['공도읍'],
#  '287': ['떡볶이', '안성'],
#  '288': ['진안동'],
#  '289': ['처인구'],
#  '290': ['닭', '닭발', '발', '계란', '계란후라이', '후라이', '서울대입구'],
#  '291': ['불로동'],
#  '292': ['퇴계원면'],
#  '293': ['브런', '카페', '삼송'],
#  '294': ['봉곡동'],
#  '295': ['떡볶이', '마산'],
#  '296': ['다',
#   '다이닝카페',
#   '이닝',
#   '카페',
#   '인과',
#   '요리',
#   '입가심',
#   '커피',
#   '곳',
#   '이동',
#   '판매',
#   '주문',
#   '츄',
#   '츄천해',
#   '천해',
#   '파스타',
#   '피자',
#   '당진'],
#  '297': ['쉬', '뷔페', '청주'],
#  '298': ['귀래면'],
#  '299': ['진영읍'],
#  '300': ['고흥'],
#  '301': ['부대', '부대찌개', '찌개', '여수'],
#  '302': ['평거동'],
#  '303': ['의정부2동'],
#  '304': ['광명동'],
#  '305': ['음식',
#   '맛',
#   '유린기',
#   '여',
#   '기본',
#   '기본안주',
#   '안주',
#   '이자',
#   '연',
#   '연어회',
#   '어회',
#   '김해'],
#  '306': ['횟집', '매운탕', '죽도동'],
#  '307': ['치즈', '치즈스틱', '스틱', '맥주', '전대'],
#  '308': ['치즈', '치즈스틱', '스틱', '위례'],
#  '309': ['광교'],
#  '310': ['치즈', '치즈스틱', '스틱', '커피', '안양일번가'],
#  '311': ['소흘읍'],
#  '312': ['비전본동'],
#  '313': ['내촌면'],
#  '314': ['술집', '칠', '칠리새우', '리', '새우', '진주'],
#  '315': ['마카롱', '카페', '부산대'],
#  '316': ['위치',
#   '점',
#   '아',
#   '베이커리',
#   '사장님',
#   '친절',
#   '디저트',
#   '디저트카페',
#   '카페',
#   '부천',
#   '베이커리',
#   '빨',
#   '빨미',
#   '미',
#   '레',
#   '하나',
#   '포장',
#   '커피',
#   '풍미',
#   '부족',
#   '곳',
#   '디저트',
#   '디저트카페',
#   '카페',
#   '부천'],
#  '317': ['비전동'],
#  '318': ['한잔',
#   '곳',
#   '칵테일',
#   '때',
#   '처음',
#   '바텐더',
#   '분',
#   '맘',
#   '주문',
#   '가게',
#   '자가',
#   '이름',
#   '이름값',
#   '값',
#   '11',
#   '11개임',
#   '개',
#   '임',
#   '친구',
#   '밥',
#   '부족',
#   '듯',
#   '칵테일',
#   '칵테일바',
#   '바',
#   '서면'],
#  '319': ['티', '티룸', '룸', '홍차', '경주'],
#  '320': ['해물', '해물칼국수', '칼국수', '대부도'],
#  '321': ['조개', '조개찜', '찜', '횟집', '안산'],
#  '322': ['일광면'],
#  '323': ['홍대'],
#  '324': ['여수'],
#  '325': ['초밥', '상수역'],
#  '326': ['상동'],
#  '327': ['가격',
#   '사악',
#   '요리',
#   '요리전문점',
#   '전문점',
#   '맛',
#   '나',
#   '자장',
#   '짬뽕',
#   '추천',
#   '적',
#   'ㅎ',
#   '중식',
#   '짜장면',
#   '삼성동',
#   '특급',
#   '특급호텔',
#   '호텔',
#   '20',
#   '20년',
#   '년',
#   '이상',
#   '경력',
#   '중식',
#   '쉐프',
#   '요리',
#   '수',
#   '곳',
#   '가격',
#   '중화',
#   '중화요리',
#   '점심시간',
#   '제공',
#   '런치',
#   '메뉴',
#   '식사',
#   '외',
#   '단돈',
#   '9000',
#   '9000원',
#   '원',
#   '맛',
#   '미니',
#   '미니요리',
#   '메인',
#   '면',
#   '면요리',
#   '국물',
#   '내공',
#   '깊이',
#   '개인적',
#   '해물',
#   '해물우동',
#   '우동',
#   '일반적',
#   '맛과',
#   '나',
#   '키',
#   '짬뽕',
#   '진',
#   '그릇',
#   '장점',
#   '아이러니',
#   '직장인',
#   '끼',
#   '점심',
#   '점심식사',
#   '단점',
#   '사무실',
#   '밀집',
#   '선',
#   '선릉역',
#   '릉',
#   '역',
#   '인근',
#   '대치',
#   '대치동',
#   '동',
#   '먹자',
#   '먹자골목',
#   '골목',
#   '위치',
#   '월요일',
#   '휴무',
#   '중식',
#   '짜장면',
#   '삼성동'],
#  '328': ['식물', '혼자', '카페', '커피맛', '쏘쏘합니', '카페', '우두동'],
#  '329': ['즉석', '즉석떡볶이', '떡볶이', '동탄'],
#  '330': ['지변동'],
#  '331': ['nan'],
#  '332': ['돼지', '돼지부속', '부속', '문막'],
#  '333': ['돼지', '돼지부속', '부속', '원주'],
#  '334': ['돼지', '돼지부속', '부속', '돼지껍데기', '껍데기', '원주'],
#  '335': ['12,300',
#   '12,300원',
#   '원',
#   '삼겹살',
#   '막창',
#   '불',
#   '불막창',
#   '대패',
#   '대패삼겹살',
#   '등',
#   '수',
#   '있음',
#   '고기',
#   '무한',
#   '무한리필집',
#   '리',
#   '필집',
#   '특유',
#   '맛',
#   '번',
#   '리필',
#   '무한리필',
#   '음료',
#   '포함',
#   '2',
#   '2천원',
#   '천',
#   '355',
#   '라',
#   '주기',
#   '양이',
#   '부족',
#   '고기집',
#   '집',
#   '재',
#   '재방문',
#   '방문',
#   '의사',
#   '막창',
#   '막창무한리필',
#   '무한',
#   '리필',
#   '둔산동'],
#  '336': ['약사동'],
#  '337': ['막창', '서면'],
#  '338': ['막창', '울산'],
#  '339': ['양념', '양념불고기', '불고기', '막창', '서창'],
#  '340': ['진해'],
#  '341': ['막창', '성건동'],
#  '342': ['막창', '일광면'],
#  '343': ['막창', '삼겹살', '일산지'],
#  '344': ['막창', '삼겹살', '명촌'],
#  '345': ['막창', '구영리'],
#  '346': ['양념', '양념불고기', '불고기', '막창', '삼산'],
#  '347': ['짜장면', '중국집', '물금읍'],
#  '348': ['항남동'],
#  '349': ['수택동'],
#  '350': ['코다리', '코다리찜', '찜', '동촌유원지'],
#  '351': ['nan'],
#  '352': ['백석동'],
#  '353': ['본오동'],
#  '354': ['포차', '두부', '두부김치', '김치', '김해시'],
#  '355': ['항남동'],
#  '356': ['신월동'],
#  '357': ['횟집', '수원인계동'],
#  '358': ['오징어', '구월동'],
#  '359': ['태인동'],
#  '360': ['횟집', '안산'],
#  '361': ['카페', '브런', '마도면'],
#  '362': ['곤지암읍'],
#  '363': ['오뎅', '전주'],
#  '364': ['오뎅', '오뎅바', '바', '전주'],
#  '365': ['동천동'],
#  '366': ['카페', '후포'],
#  '367': ['밥집', '당산동'],
#  '368': ['카페', '상무지구'],
#  '369': ['소고기', '샴페인', '송도'],
#  '370': ['뼈', '뼈해장국', '해장국', '영등포구청역'],
#  '371': ['양',
#   '토마토',
#   '토마토스튜',
#   '스튜',
#   '풍기',
#   '풍기리조',
#   '리',
#   '조',
#   '예약',
#   '예약금',
#   '1',
#   '1만원',
#   '만',
#   '원',
#   '송금',
#   '현금가',
#   '2',
#   '2천원',
#   '천',
#   '휴',
#   '파스타',
#   '리',
#   '리조',
#   '조',
#   '대학로',
#   '양이',
#   '편',
#   '메뉴',
#   '풍기',
#   '풍기리조',
#   '리',
#   '조',
#   '파스타',
#   '리',
#   '리조',
#   '조',
#   '대학로'],
#  '372': ['입안',
#   '느낌',
#   '나',
#   '돈',
#   '돈코츠',
#   '코',
#   '츠',
#   '라멘',
#   '식',
#   '식감이',
#   '감이',
#   '맛',
#   '남',
#   '개인적',
#   '취향',
#   '자체',
#   '대신',
#   '차슈',
#   '말',
#   '입',
#   '차슈추',
#   '라멘',
#   '돈',
#   '돈코츠라멘',
#   '코',
#   '츠',
#   '신당동'],
#  '373': ['위치',
#   '분위기',
#   '대화',
#   '정도',
#   '노래',
#   '티나',
#   '아메리카',
#   '아메리카노',
#   '노',
#   '맛',
#   '보통',
#   '흑임자',
#   '흑임자빙수',
#   '빙수',
#   '카페',
#   '연희동'],
#  '374': ['효목동'],
#  '375': ['가산동'],
#  '376': ['카페', '커피', '구월동'],
#  '377': ['횟집', '초밥', '대전'],
#  '378': ['청룡동'],
#  '379': ['샐러드', '샌드위치', '교대역'],
#  '380': ['퓨', '퓨전포차', '전', '포차', '파', '파불고기', '불고기', '구로디지털단지역'],
#  '381': ['술집', '떡볶이', '홍대'],
#  '382': ['포차', '부개역'],
#  '383': ['파스타', '브런', '광주'],
#  '384': ['신평동'],
#  '385': ['카페', '마산'],
#  '386': ['케익', '커피', '목포'],
#  '387': ['동금동'],
#  '388': ['모라동'],
#  '389': ['사장님',
#   '친절',
#   '슈페너',
#   '맛',
#   '인생',
#   '등극',
#   '눈꽃',
#   '눈꽃빙수',
#   '빙수',
#   '카페',
#   '원주',
#   '인테리어',
#   '분위기',
#   '티타임',
#   '보내기',
#   '눈꽃',
#   '눈꽃빙수',
#   '빙수',
#   '카페',
#   '원주',
#   '슈페너',
#   '유명',
#   '데',
#   '곳',
#   '케이크',
#   '눈꽃',
#   '눈꽃빙수',
#   '빙수',
#   '카페',
#   '원주'],
#  '390': ['성수역'],
#  '391': ['심곡동'],
#  '392': ['카페', '신둔면'],
#  '393': ['막창', '연신내'],
#  '394': ['막창', '생', '생막창', '아산'],
#  '395': ['모임', '제격', '곳', '코스', '코스요리', '요리', '제대', '예정', '이닝', '레스토랑', '앞산'],
#  '396': ['횟집', '조개', '조개찜', '찜', '대부도'],
#  '397': ['삼계탕', '카페', '김해'],
#  '398': ['술집', '화덕', '화덕피자', '피자', '전주'],
#  '399': ['계산동'],
#  '400': ['레스토랑', '필', '필라프', '라프', '둔산동'],
#  '401': ['중동'],
#  '402': ['의정부동'],
#  '403': ['커피', '고령'],
#  '404': ['닭', '닭갈비', '갈비', '숯불', '숯불닭갈비', '춘천'],
#  '405': ['맛',
#   '가격',
#   '예정',
#   '철판',
#   '고기',
#   '고기집',
#   '집',
#   '사당역',
#   '1',
#   '3',
#   '5',
#   '7',
#   '중',
#   '대패',
#   '대패삼겹살',
#   '삼겹살',
#   '김',
#   '특이',
#   '맛',
#   '맛있음',
#   '있음',
#   '나머지',
#   '데',
#   '철판',
#   '고기',
#   '고기집',
#   '집',
#   '사당역',
#   '메뉴',
#   '고기',
#   '두께',
#   '구',
#   '구분되',
#   '분되',
#   '특이',
#   '가게',
#   '사당',
#   '사당역',
#   '역',
#   '유명',
#   '맛',
#   '맛집이',
#   '집이',
#   '티비',
#   '방송',
#   '맛집',
#   '집',
#   '소개',
#   '7',
#   '삼겹살',
#   '생각',
#   '3',
#   '대패',
#   '5',
#   '일반',
#   '볶음밥',
#   '보시',
#   '보시길',
#   '길',
#   '바',
#   '바래요',
#   '래요',
#   '아',
#   '양',
#   '1',
#   '분',
#   '주문',
#   '철판',
#   '고기',
#   '고기집',
#   '집',
#   '사당역',
#   '전체적',
#   '고기',
#   '내도',
#   '맛',
#   '된장찌개',
#   '예술이넹',
#   '기본',
#   '홍합탕',
#   '철판',
#   '고기',
#   '고기집',
#   '집',
#   '사당역',
#   '번째',
#   '방문',
#   '성비',
#   '맛',
#   '고기',
#   '때',
#   '명이',
#   '명이나물',
#   '나물',
#   '주고',
#   '쌈',
#   '셀프',
#   '수',
#   '볶음밥',
#   '계란',
#   '치즈',
#   '중',
#   '선택',
#   '철판',
#   '고기',
#   '고기집',
#   '집',
#   '사당역'],
#  '406': ['삼겹살', '삼겹살무한리필', '무한', '리필', '단국대'],
#  '407': ['귤', '귤쥬스', '쥬스', '국수', '단국대학교'],
#  '408': ['족발', '둔산동'],
#  '409': ['튀김', '어묵', '사직동'],
#  '410': ['떡볶이', '불당동'],
#  '411': ['떡볶이', '우동', '완전', '스탈', '튀김', '어묵', '세종시'],
#  '412': ['어묵', '튀김', '남포동'],
#  '413': ['튀김', '떡볶이', '보람동'],
#  '414': ['떡볶이', '튀김', '고창'],
#  '415': ['의정부동'],
#  '416': ['태장동'],
#  '417': ['고기', '고기집', '집', '갈비', '대학로'],
#  '418': ['식전',
#   '샐러드',
#   '장국',
#   '만',
#   '뒤',
#   '메인',
#   '매',
#   '매뉴',
#   '뉴',
#   '전체적',
#   '밥',
#   '밥양이',
#   '양이',
#   '여성',
#   '기준',
#   '남자',
#   '겐',
#   '느낌',
#   '음식',
#   '전반적',
#   '신선',
#   '닷',
#   '닷지에',
#   '지에',
#   '주방',
#   '동안',
#   '눈',
#   '깃',
#   '깃거리',
#   '거리',
#   '건',
#   '서비스',
#   '서비스부분',
#   '부분',
#   '홀',
#   '전문적',
#   '직원',
#   '제가',
#   '번',
#   '주방안',
#   '안',
#   '눈치',
#   '자리',
#   '안내',
#   '메뉴판',
#   '개선',
#   '혼자',
#   '손님',
#   '거',
#   '외',
#   '거리감',
#   '메밀',
#   '가마솥',
#   '가마솥밥',
#   '밥',
#   '논현동',
#   '음식',
#   '전체적',
#   '메밀',
#   '메밀김밥',
#   '김밥',
#   '새우',
#   '메밀',
#   '가마솥',
#   '가마솥밥',
#   '밥',
#   '논현동',
#   '점심시간',
#   '직장인',
#   '메밀',
#   '메밀김밥',
#   '김밥',
#   '짱',
#   '짱맛임',
#   '맛',
#   '임',
#   '장어',
#   '가격',
#   '감',
#   '메밀',
#   '가마솥',
#   '가마솥밥',
#   '밥',
#   '논현동',
#   '메밀',
#   '메밀김밥',
#   '김밥',
#   '강추',
#   '분위기',
#   '퓨',
#   '퓨전일식',
#   '전',
#   '일식',
#   '수',
#   '식당',
#   '메밀',
#   '가마솥',
#   '가마솥밥',
#   '밥',
#   '논현동',
#   '일식',
#   '메뉴',
#   '맛',
#   '수',
#   '부담',
#   '근방',
#   '가게',
#   '중',
#   '가격',
#   '편',
#   '메밀',
#   '메밀김밥',
#   '김밥',
#   '기본',
#   '메밀',
#   '가마솥',
#   '가마솥밥',
#   '밥',
#   '논현동'],
#  '419': ['성비',
#   '이외',
#   '평가',
#   '불가능',
#   '판',
#   '정도',
#   '맛',
#   '입맛',
#   '분',
#   '개',
#   '소고',
#   '소고기무',
#   '기무',
#   '리필',
#   '생고기',
#   '작전동'],
#  '420': ['소고', '소고기무', '기무', '리필', '면목동'],
#  '421': ['닭', '광주'],
#  '422': ['에버랜드'],
#  '423': ['상도동'],
#  '424': ['파스타', '피자', '사당역'],
#  '425': ['오징어', '술집', '경성대'],
#  '426': ['해물', '삼', '삼합', '합', '공화동'],
#  '427': ['대림'],
#  '428': ['차돌', '차돌박이', '박이', '초밥', '충주'],
#  '429': ['스파게티', '레스토랑', '성남'],
#  '430': ['대구',
#   '뼈다귀',
#   '장국',
#   '대기',
#   '동네',
#   '동네맛집',
#   '맛',
#   '집',
#   '홍',
#   '홍천뚝배기',
#   '천',
#   '뚝배기',
#   '곳',
#   '국물',
#   '스타일',
#   '특별',
#   '점',
#   '매운맛',
#   '술꾼',
#   '추천',
#   '뼈다귀',
#   '장국',
#   '탕수육',
#   '두산동'],
#  '431': ['연곡면'],
#  '432': ['느낌', '파스타', '때', '곳', '신흥3동'],
#  '433': ['브런', '카페', '포항'],
#  '434': ['수제', '수제맥주', '맥주', '장기동'],
#  '435': ['사장님', '내외분', '친절', '음식', '단골', '곳', '브런', '카페', '광교'],
#  '436': ['양',
#   '커피',
#   '기본',
#   '투',
#   '투샷',
#   '샷',
#   '맛',
#   '넘',
#   '진해',
#   '우유',
#   '정도',
#   '잔',
#   '듯',
#   '바닐라',
#   '라',
#   '라떼',
#   '떼',
#   '시럽',
#   '싸구려',
#   '싸구려맛',
#   '커피',
#   '카페',
#   '안암'],
#  '437': ['북신동'],
#  '438': ['카페', '마산'],
#  '439': ['맥주', '오동동'],
#  '440': ['레스토랑', '파스타', '유성'],
#  '441': ['커피', '원두', '수', '좋앗어', '브런치', '식사', '듯', '방문', '창우동'],
#  '442': ['화명동'],
#  '443': ['흑', '흑돼지', '돼지', '돼지고기', '신월동'],
#  '444': ['수육', '수육국밥', '국밥', '갈비찜', '목원대'],
#  '445': ['마전동'],
#  '446': ['짜장면',
#   '보통',
#   '양이',
#   '편이',
#   '대자',
#   '계란',
#   '정도',
#   '차이',
#   '화장실',
#   '짜장면',
#   '만두',
#   '전주'],
#  '447': ['대신동'],
#  '448': ['안중읍'],
#  '449': ['부대', '부대찌개', '찌개', '명지대'],
#  '450': ['광명동'],
#  '451': ['망월동'],
#  '452': ['불고기', '불고기백반', '백반', '백반집', '집', '익산'],
#  '453': ['장지동'],
#  '454': ['외동'],
#  '455': ['연포탕', '낙지', '충주'],
#  '456': ['낙지', '연포탕', '한남동'],
#  '457': ['nan'],
#  '458': ['괴안동'],
#  '459': ['용인',
#   '수지',
#   '보정',
#   '보정동',
#   '동',
#   '위치',
#   '153',
#   '153닭갈비',
#   '닭',
#   '갈비',
#   '춘천',
#   '가지',
#   '정도',
#   '일주일',
#   '한번',
#   '나',
#   '맛',
#   '맛집',
#   '집',
#   '닭',
#   '닭갈비',
#   '갈비',
#   '보정동'],
#  '460': ['심곡동'],
#  '461': ['부발읍'],
#  '462': ['아구', '아구찜', '찜', '삼정동'],
#  '463': ['부대',
#   '부대찌개',
#   '찌개',
#   '햄버거',
#   '둘',
#   '옛날',
#   '맛',
#   '다',
#   '바',
#   '가격',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '햄버거',
#   '군산',
#   '포장',
#   '포장가능',
#   '가능',
#   '마늘',
#   '맛',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '부담',
#   '다음',
#   '제육',
#   '도전',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '햄버거',
#   '군산'],
#  '464': ['방촌동'],
#  '465': ['오산동'],
#  '466': ['안중읍'],
#  '467': ['샤브샤브', '칼국수', '대관령'],
#  '468': ['내촌면'],
#  '469': ['nan'],
#  '470': ['nan'],
#  '471': ['nan'],
#  '472': ['횟집', '백석동'],
#  '473': ['보쌈', '경산'],
#  '474': ['굴', '굴보쌈', '보쌈', '연산'],
#  '475': ['서현'],
#  '476': ['기안동'],
#  '477': ['팽성읍'],
#  '478': ['포승읍'],
#  '479': ['콩나물', '콩나물국밥', '국밥', '건대'],
#  '480': ['삼겹살', '파', '파불고기', '불고기', '안산'],
#  '481': ['부대', '부대찌개', '찌개', '율동공원'],
#  '482': ['부대', '부대찌개', '찌개', '이천'],
#  '483': ['점심',
#   '저녁',
#   '주인',
#   '부부',
#   '친절',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '동탄',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '분',
#   '추천',
#   '맛',
#   '맛집',
#   '집',
#   '인테리어',
#   '란',
#   '건',
#   '인정',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '동탄'],
#  '484': ['서비스',
#   '맛',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '클레임',
#   '1',
#   '우리',
#   '종업원',
#   '거',
#   '2',
#   '우리',
#   '가게',
#   '말',
#   '3',
#   '정말',
#   '개념',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '용인',
#   '본점',
#   '데로',
#   '여기',
#   '메인',
#   '메인서버분',
#   '서버',
#   '분',
#   '마인드',
#   '서비스',
#   '서비스업종',
#   '업종',
#   '듯',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '용인',
#   '반찬',
#   '중',
#   '그것',
#   '손님',
#   '뭐',
#   '10',
#   '10번',
#   '번',
#   '주문',
#   '거',
#   '엉망',
#   '맛',
#   '임',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '용인'],
#  '485': ['보정동'],
#  '486': ['153',
#   '153포',
#   '포',
#   '츠',
#   '츠부대찌개',
#   '부대',
#   '찌개',
#   '염',
#   '염식',
#   '식',
#   '특허',
#   '부대찌개',
#   '유명',
#   '재료',
#   '정성',
#   '담는',
#   '함박',
#   '함박스테이크',
#   '스테이크',
#   '성비',
#   '짱',
#   '고요',
#   '퀘',
#   '퀘사디',
#   '사',
#   '디',
#   '여',
#   '여친',
#   '친',
#   '무엇',
#   '쟈료',
#   '국산',
#   '김치',
#   '김치라',
#   '라',
#   '부대찌',
#   '찌',
#   '뭐',
#   '해도',
#   '햄',
#   '중요',
#   '부대',
#   '부대찌개',
#   '찌개',
#   '퀘',
#   '퀘사디',
#   '사',
#   '디',
#   '불당동'],
#  '487': ['부대', '부대찌개', '찌개', '남산타워'],
#  '488': ['부대', '부대찌개', '찌개', '한식', '일산'],
#  '489': ['부대', '부대찌개', '찌개', '오성면'],
#  '490': ['한방', '한방삼계탕', '삼계탕', '용현동'],
#  '491': ['대곶면'],
#  '492': ['사노동'],
#  '493': ['국지', '민물', '민물매운탕', '매운탕', '후암동'],
#  '494': ['엄사면'],
#  '495': ['울산대'],
#  '496': ['이곳',
#   '별',
#   '다섯',
#   '다섯개',
#   '개',
#   '자연산',
#   '버섯',
#   '버섯전골',
#   '전골',
#   '맛',
#   '맛집',
#   '집',
#   '현지',
#   '현지인의',
#   '인의',
#   '적극적',
#   '추천',
#   '곳',
#   '코',
#   '점포',
#   '점포명이',
#   '명이',
#   '153',
#   '153매운탕',
#   '매운탕',
#   '기재',
#   '모든',
#   '간판',
#   '명함',
#   '등',
#   '비',
#   '153해장국',
#   '해',
#   '장국',
#   '확인',
#   '개인적',
#   '최고',
#   '메뉴',
#   '지인',
#   '소개',
#   '본인',
#   '동반자',
#   '모두',
#   '종류',
#   '양',
#   '국물',
#   '안',
#   '골프장',
#   '주변',
#   '유명',
#   '선수',
#   '유명인',
#   '사인',
#   '진양',
#   '진양밸리',
#   '밸리',
#   '젠스',
#   '젠스필드',
#   '필드',
#   '근처',
#   '라운딩',
#   '전',
#   '후',
#   '식사',
#   '강추',
#   '그',
#   '일',
#   '한번',
#   '방문',
#   '권장',
#   '경우',
#   '전화',
#   '예약',
#   '황태',
#   '황태해장국',
#   '해장국',
#   '일죽',
#   '잰스',
#   '잰스필드',
#   '필드',
#   '운동',
#   '때',
#   '곳',
#   '정국',
#   '밑반찬',
#   '황태',
#   '황태해장국',
#   '해장국',
#   '일죽'],
#  '497': ['장호원읍'],
#  '498': ['안현동'],
#  '499': ['맥주집', '간석역'],
#  '500': ['물닭', '물닭갈비', '갈비', '닭', '닭갈비', '하이원'],
#  '501': ['맥주', '하안동'],
#  '502': ['하안4동'],
#  '503': ['궁동'],
#  '504': ['매호동'],
#  '505': ['마카롱', '디저트', '디저트카페', '카페', '동탄'],
#  '506': ['nan'],
#  '507': ['화도읍'],
#  '508': ['커피', '순천향대'],
#  '509': ['술집', '맥주', '종로'],
#  '510': ['nan'],
#  '511': ['피규어',
#   '담',
#   '방문',
#   '방문예정',
#   '예정',
#   '크레페',
#   '카페',
#   '천호',
#   '메뉴',
#   '편',
#   '제가',
#   '크레페',
#   '본적',
#   '처음',
#   '봣',
#   '데',
#   '이곳',
#   '맛',
#   '맛집',
#   '집',
#   '저',
#   '입맛',
#   '인건',
#   '음료',
#   '아메리카',
#   '아메리카노',
#   '노',
#   '편이',
#   '라',
#   '라떼',
#   '떼',
#   '고소',
#   '크레페',
#   '카페',
#   '천호'],
#  '512': ['점심때',
#   '방문',
#   '점심',
#   '메뉴',
#   '주변',
#   '식당',
#   '편',
#   '전체적',
#   '분위기',
#   '맛',
#   '때문',
#   '음식점',
#   '추천',
#   '고급',
#   '느낌',
#   '저녁',
#   '와인',
#   '와인바',
#   '바',
#   '운영',
#   '와인',
#   '와인바',
#   '바',
#   '레스토랑',
#   '강남구청역'],
#  '513': ['곱창', '곱창전골', '전골', '거두리'],
#  '514': ['레몬', '이드', '카페', '경포'],
#  '515': ['강문동'],
#  '516': ['비프',
#   '비프랜차이즈',
#   '랜',
#   '차',
#   '이즈',
#   '고로케',
#   '집',
#   '개',
#   '개당',
#   '당',
#   '800',
#   '800원',
#   '원',
#   '2000',
#   '2000원',
#   '가격',
#   '맛',
#   '원',
#   '3',
#   '3개',
#   '하면',
#   '2',
#   '2천원',
#   '천',
#   '가심',
#   '가심비',
#   '비',
#   '애용',
#   '오픈',
#   '초기',
#   '오후',
#   '6',
#   '6시',
#   '시',
#   '나',
#   '다양',
#   '사시',
#   '걸',
#   '추천',
#   '고로케',
#   '커피',
#   '통영'],
#  '517': ['주차장',
#   '카페',
#   '핑크뮬리',
#   '유명',
#   '방문',
#   '소금',
#   '소금커피',
#   '커피',
#   '시',
#   '처',
#   '가격',
#   '가격대비',
#   '대비',
#   '넘',
#   '맛',
#   '스튜',
#   '커피',
#   '현풍'],
#  '518': ['카페', '창동'],
#  '519': ['카페', '현풍'],
#  '520': ['커피', '주문진'],
#  '521': ['신내동'],
#  '522': ['홍대'],
#  '523': ['어곡동'],
#  '524': ['처인구'],
#  '525': ['처인구'],
#  '526': ['도시락', '추억', '초량'],
#  '527': ['빵집', '카페', '초량'],
#  '528': ['삼계동'],
#  '529': ['작당',
#   '작당모의',
#   '모의',
#   '곳',
#   '내부',
#   '테이블',
#   '음료',
#   '케이크',
#   '가격',
#   '편',
#   '연',
#   '연남',
#   '연남동',
#   '남동',
#   '동',
#   '동네',
#   '특성',
#   '생각',
#   '납득',
#   '가능',
#   '정도',
#   '초',
#   '초코케이크',
#   '코',
#   '브라우니',
#   '빵',
#   '위',
#   '코크림',
#   '크림',
#   '블루',
#   '블루베리',
#   '베리',
#   '피치',
#   '피치트로피컬망고',
#   '트로피컬',
#   '망고',
#   '기대',
#   '티',
#   '친구',
#   '레모',
#   '이드',
#   '내가',
#   '먹',
#   '파스타',
#   '레스토랑',
#   '연남동',
#   '만조',
#   '만조크림파스타',
#   '크림',
#   '파스타',
#   '대신',
#   '제철',
#   '일리',
#   '일리코',
#   '코',
#   '치즈',
#   '치즈피자',
#   '피자',
#   '2',
#   '2차',
#   '차',
#   '방문',
#   '쏘쏘',
#   '종류',
#   '피',
#   '피타이',
#   '타이',
#   '파스타',
#   '레스토랑',
#   '연남동'],
#  '530': ['구로1동'],
#  '531': ['북정동'],
#  '532': ['공부',
#   '방문',
#   '카페',
#   '서울',
#   '수',
#   '커피',
#   '가격',
#   '맛',
#   '음료',
#   '커피계열',
#   '계열',
#   '디저트',
#   '기성품',
#   '무엇',
#   '맘',
#   '건',
#   '쌍',
#   '쌍암공원',
#   '암',
#   '공원',
#   '개',
#   '중',
#   '뷰',
#   '카페',
#   '커피',
#   '첨단'],
#  '533': ['삼겹살', '두류동'],
#  '534': ['기대', '기대안', '안', '디저트', '땅', '햇볕', '손님', '조아', '카페', '브런', '대흥'],
#  '535': ['동패동'],
#  '536': ['칼국수', '동동주', '대부도'],
#  '537': ['백종',
#   '백종원골목식당',
#   '원',
#   '골목',
#   '식당',
#   '집',
#   '30',
#   '30분정도',
#   '분',
#   '정도',
#   '대기',
#   '피자',
#   '음료',
#   '수',
#   '곳',
#   '개인적',
#   '포',
#   '포치즈',
#   '치즈',
#   '강추',
#   '게살',
#   '리코',
#   '명란',
#   '사장님',
#   '음식',
#   '계산',
#   '직접',
#   '인사',
#   '인상',
#   '인상적임',
#   '적임',
#   '본방',
#   '본방사수',
#   '사수',
#   '관계',
#   '친숙',
#   '느낌',
#   '근처',
#   '근처가면',
#   '가면',
#   '포장',
#   '피자',
#   '회기'],
#  '538': ['타르트', '양산'],
#  '539': ['타르트', '카페', '물금읍'],
#  '540': ['타르트',
#   '흑당',
#   '흑당밀크티',
#   '밀크',
#   '티',
#   '처음',
#   '밀크티',
#   '단맛',
#   '균형',
#   '실내',
#   '편',
#   '모임',
#   '가능',
#   '공간',
#   '카페',
#   '베이커리',
#   '신촌역'],
#  '541': ['1',
#   '1박2일',
#   '박',
#   '2',
#   '일',
#   '한옥',
#   '한옥마을',
#   '마을',
#   '중',
#   '최고',
#   '인절미',
#   '인절미아이스크림',
#   '아이스',
#   '아이스크림',
#   '크림',
#   '인절미',
#   '카페',
#   '전주한옥마을'],
#  '542': ['동네',
#   '172',
#   '172후라이',
#   '후라이',
#   '라이스',
#   '곳',
#   '친절',
#   '철판',
#   '철판볶음밥',
#   '볶음밥',
#   '철판볶음밥전문',
#   '전문',
#   '화정동'],
#  '543': ['술집', '맥주', '남포동'],
#  '544': ['여주'],
#  '545': ['강화도'],
#  '546': ['새우',
#   '손질',
#   '대명',
#   '대명항',
#   '항',
#   '때',
#   '제대',
#   '새우튀김',
#   '튀김',
#   '수',
#   '고소',
#   '기름',
#   '새우',
#   '새우튀김',
#   '튀김',
#   '튀김전문',
#   '전문',
#   '대명항',
#   '손님',
#   '경우',
#   '어수',
#   '어수선',
#   '선',
#   '튀김',
#   '일반',
#   '새우',
#   '새우튀김',
#   '튀김',
#   '튀김전문',
#   '전문',
#   '대명항',
#   '새우',
#   '새우튀김',
#   '튀김',
#   '고소',
#   '맛',
#   '수제',
#   '피클',
#   '나',
#   '새우',
#   '새우튀김',
#   '튀김',
#   '튀김전문',
#   '전문',
#   '대명항'],
#  '547': ['갈매기', '갈매기살', '살', '제육', '제육쌈밥', '쌈', '밥', '오리역'],
#  '548': ['카페', '처인구'],
#  '549': ['집', '집밥', '밥', '두산동'],
#  '550': ['코',
#   '코맛',
#   '맛',
#   '아이스',
#   '아이스크림',
#   '크림',
#   '처음',
#   '당',
#   '당ㅇ',
#   'ㅇ',
#   '케이크',
#   '테이크',
#   '테이크아웃',
#   '아웃',
#   '1200',
#   '1200원',
#   '원',
#   '할인',
#   '날',
#   '때',
#   '사서',
#   '숲길',
#   '코케이크',
#   '듯',
#   '초콜릿',
#   '초콜릿카페',
#   '카페',
#   '연남동',
#   '초콜릿',
#   '맛',
#   '초콜릿',
#   '초콜릿카페',
#   '카페',
#   '연남동',
#   '리',
#   '초콜릿',
#   '공장',
#   '강',
#   '그거',
#   '여기',
#   '베스트',
#   '음료',
#   '모금',
#   '700',
#   '700원',
#   '원',
#   '생각',
#   '만큼',
#   '성비',
#   '데',
#   '인생',
#   '건',
#   '단언',
#   '정도',
#   '가치',
#   '순식간',
#   '사진',
#   '잔',
#   '예의',
#   '향',
#   '식',
#   '식감',
#   '감',
#   '나',
#   '도달',
#   '때',
#   '거',
#   '감동',
#   '선사',
#   '상상',
#   '수',
#   '매장',
#   '화이트',
#   '화이트톤',
#   '톤',
#   '앞쪽',
#   '연',
#   '연트럴파크',
#   '트럴',
#   '파크',
#   '채광',
#   '풍경',
#   '편',
#   '예스',
#   '예스키즈존',
#   '키즈',
#   '존',
#   '점',
#   '마음',
#   '동시',
#   '룰',
#   '엄격',
#   '주말',
#   '2',
#   '2시간',
#   '시간',
#   '이용',
#   '1',
#   '1인',
#   '인',
#   '1주문',
#   '주문',
#   '방문',
#   '고려',
#   '초콜릿',
#   '초콜릿카페',
#   '카페',
#   '연남동',
#   '경의',
#   '경의중앙선',
#   '중앙선',
#   '근처',
#   '근처라',
#   '라',
#   '가기',
#   '디저트',
#   '편',
#   '초콜릿',
#   '초콜릿카페',
#   '카페',
#   '연남동'],
#  '551': ['당고', '당고개역'],
#  '552': ['소라면'],
#  '553': ['닭', '닭한마리', '한마리', '지', '양정'],
#  '554': ['술집', '이천'],
#  '555': ['음식',
#   '분위기',
#   '서비스',
#   '애',
#   '애피타이저',
#   '피',
#   '타이',
#   '저',
#   '새우',
#   '새우스파게피스',
#   '스파',
#   '게',
#   '피스',
#   '시랑',
#   '디저트',
#   '푸딩',
#   '파스타',
#   '화덕',
#   '화덕피자',
#   '피자',
#   '부산대',
#   '가격',
#   '테',
#   '처음',
#   '면',
#   '과자',
#   '마지막',
#   '푸딩',
#   '코스',
#   '맛',
#   '파스타',
#   '화덕',
#   '화덕피자',
#   '피자',
#   '부산대',
#   '메인',
#   '메인음식',
#   '음식',
#   '전',
#   '에피타이져',
#   '디저트',
#   '가격',
#   '성비',
#   '친절',
#   '사람',
#   '부산',
#   '부산대',
#   '대',
#   '양식',
#   '맛',
#   '파스타',
#   '화덕',
#   '화덕피자',
#   '피자',
#   '부산대'],
#  '556': ['nan'],
#  '557': ['릭',
#   '릭요거트',
#   '요거트',
#   '샐러드',
#   '곳',
#   '안',
#   '1',
#   '1인용',
#   '인',
#   '용',
#   '의자',
#   '개',
#   '정도',
#   '대부분',
#   '테이크',
#   '테이크아웃해',
#   '아웃',
#   '해',
#   '끼',
#   '수',
#   '밀크',
#   '밀크티',
#   '티',
#   '요거트',
#   '외대'],
#  '558': ['술집', '포차', '상무지구'],
#  '559': ['매장',
#   '매장안',
#   '안',
#   '포장',
#   '생각',
#   'ㅠ',
#   '우선',
#   '개인적',
#   '떡',
#   '음청',
#   '요',
#   '떡볶이',
#   '튀김',
#   '수제',
#   '수제튀김',
#   '튀김',
#   '떡볶이',
#   '세종시'],
#  '560': ['수제', '수제튀김', '튀김', '돈까스', '반석'],
#  '561': ['창전동'],
#  '562': ['카페', '커피', '건대'],
#  '563': ['라',
#   '라떼',
#   '떼',
#   '일본',
#   '브르',
#   '브르클린만',
#   '클린',
#   '만',
#   '맛',
#   '나',
#   '비',
#   '비싸요',
#   '싸요',
#   '커피',
#   '카페',
#   '율동공원',
#   '테라스',
#   '야경',
#   '커피',
#   '데이트',
#   '데이트분위기',
#   '분위기',
#   '뷰',
#   '커피',
#   '카페',
#   '율동공원'],
#  '564': ['상현동'],
#  '565': ['이자', '사', '선릉역'],
#  '566': ['수제', '수제피자', '피자', '대치동'],
#  '567': ['포승읍'],
#  '568': ['피자', '수제', '수제피자', '노원역'],
#  '569': ['신방통정지구'],
#  '570': ['체', '체코', '코', '체코맥주', '맥주', '한남동'],
#  '571': ['쌍촌동'],
#  '572': ['상남면'],
#  '573': ['피자', '괴정동'],
#  '574': ['곱창', '곱창집', '집', '신림'],
#  '575': ['와인', '와인바', '바', '상무지구'],
#  '576': ['브런', '스테이크', '운암동'],
#  '577': ['한옥', '한옥카페', '카페', '황리단길'],
#  '578': ['펜',
#   '펜션',
#   '션',
#   '갤러리',
#   '카페',
#   '운영',
#   '모던',
#   '분위기',
#   '곳',
#   '카페',
#   '라',
#   '라떼',
#   '떼',
#   '신촌'],
#  '579': ['와인', '와인바', '바', '부천'],
#  '580': ['동네', '동네주민', '주민', '음식점', '느낌', '고기', '야탑동'],
#  '581': ['술집', '종로'],
#  '582': ['당', '모밀', '모밀국수', '국수', '서면'],
#  '583': ['코',
#   '코엑스',
#   '엑스',
#   '파',
#   '파르',
#   '르',
#   '스몰',
#   '식당',
#   '가림',
#   '가림막',
#   '막',
#   '오픈',
#   '오픈형태',
#   '형태',
#   '당',
#   '공기',
#   '공기밥',
#   '밥',
#   '세트',
#   '국물',
#   '맨밥',
#   '유부',
#   '유부초밥',
#   '초밥',
#   '후회',
#   '마한',
#   '만두',
#   '거',
#   '피',
#   '국물속',
#   '속',
#   '지느러미',
#   '혼',
#   '혼밥',
#   '당',
#   '새우',
#   '새우만두',
#   '만두',
#   '코엑스'],
#  '584': ['당', '만두', '정관'],
#  '585': ['웨이팅',
#   '산',
#   '맛',
#   '뭐',
#   '정도',
#   '왕따',
#   '왕따봉',
#   '봉',
#   '시전',
#   '양은',
#   '분식점',
#   '장터',
#   '장터국수',
#   '국수',
#   '양',
#   '인거',
#   '성비',
#   '건',
#   '생각',
#   '남포',
#   '남포동',
#   '동',
#   '본점',
#   '여기',
#   '사람',
#   '먹',
#   '서비스',
#   '저',
#   '포함',
#   '손님',
#   '3',
#   '3테이블',
#   '테이블',
#   '평가',
#   '평가하기',
#   '하기',
#   '상황',
#   '거',
#   '이야기',
#   '하면',
#   '음식',
#   '하단',
#   '하단역',
#   '역',
#   '근처',
#   '한번',
#   '볼만',
#   '하다',
#   '당',
#   '모밀',
#   '하단',
#   '예전',
#   '남포',
#   '남포동',
#   '동',
#   '서서',
#   '맛',
#   '맛집',
#   '집',
#   '분점',
#   '타지',
#   '사람',
#   '분위기',
#   '본점',
#   '식사',
#   '식사가능',
#   '가능',
#   '편',
#   '층',
#   '나름',
#   '뷰',
#   '당',
#   '모밀',
#   '하단'],
#  '586': ['당', '발', '발국수', '국수', '남천동'],
#  '587': ['때',
#   '생각',
#   '나지',
#   '오랫만',
#   '의',
#   '반복',
#   '당',
#   '당면',
#   '남포동',
#   '예상',
#   '국물',
#   '국물맛',
#   '맛',
#   '자극적',
#   '약간',
#   '저',
#   '입맛',
#   '가격',
#   '가격대비',
#   '대비',
#   '양이',
#   '부족',
#   '정도',
#   '배가',
#   '차',
#   '상태',
#   '당',
#   '당면',
#   '남포동'],
#  '588': ['김량장동'],
#  '589': ['왕십리'],
#  '590': ['순대', '순대튀김', '튀김', '김밥', '춘천'],
#  '591': ['피자', '중곡동'],
#  '592': ['피자', '조각', '조각피자', '경대북문'],
#  '593': ['피자', '피자집', '집', '산격3동'],
#  '594': ['피자', '맥주', '성서'],
#  '595': ['궁동'],
#  '596': ['피자', '치킨', '궁동'],
#  '597': ['피자', '하양'],
#  '598': ['피자', '단국대'],
#  '599': ['피자', '충북대'],
#  '600': ['고', '고깃집', '깃', '집', '고기', '고기집', '신부동'],
#  '601': ['브런',
#   '브런치',
#   '치',
#   '방문',
#   '동편',
#   '동편입구',
#   '입구',
#   '5',
#   '5분정도',
#   '분',
#   '정도',
#   '도보',
#   '도보이동거리',
#   '이동',
#   '거리',
#   '맛',
#   '양도',
#   '만족',
#   '사진',
#   '사진속',
#   '속',
#   '메뉴',
#   '1.2',
#   '1.2만원',
#   '만',
#   '원',
#   '브런',
#   '카페',
#   '동편마을'],
#  '602': ['카페', '커피', '호매실'],
#  '603': ['맥', '술집', '전주한옥마을'],
#  '604': ['커피', '군산'],
#  '605': ['북', '북카페', '카페', '곡성'],
#  '606': ['육개장', '육개장칼국수', '칼국수', '호평동'],
#  '607': ['의정부'],
#  '608': ['카페', '신암동'],
#  '609': ['카페', '신창동'],
#  '610': ['짜장면', '계대'],
#  '611': ['카페', '신방동'],
#  '612': ['커피', '흑', '흑돼지', '돼지', '분당정자'],
#  '613': ['술집', '파스타', '심곡동'],
#  '614': ['얼마', '안주', '값', '편', '2', '2차', '차', '술집', '파스타', '구월동'],
#  '615': ['안주', '반면', '술', '가격', '곳', '내부', '치킨', '맥주', '동성로'],
#  '616': ['수', '수타면', '타면', '중국집', '전주'],
#  '617': ['포차', '술집', '두정동'],
#  '618': ['곡반정동'],
#  '619': ['술집', '인계동'],
#  '620': ['흑', '흑돼지버거', '돼지', '버거', '수제', '수제버거', '애월'],
#  '621': ['흑', '흑돼지', '돼지', '햄버거', '애월읍'],
#  '622': ['음식',
#   '맛',
#   '가격',
#   '가격대비',
#   '대비',
#   '때',
#   '약간',
#   '편',
#   '보리밥',
#   '보리밥정식',
#   '정식',
#   '술집',
#   '구리',
#   '음식',
#   '음식퀄리티',
#   '퀄리티',
#   '보리밥',
#   '보리밥정식',
#   '정식',
#   '술집',
#   '구리'],
#  '623': ['정자',
#   '정자동',
#   '동',
#   '먹자',
#   '먹자골목',
#   '골목',
#   '쪽',
#   '갈비집',
#   '손님',
#   '고민',
#   '서서',
#   '서서양념',
#   '양념',
#   '갈비',
#   '서서갈비',
#   '이름',
#   '고',
#   '고깃집',
#   '깃',
#   '집',
#   '나',
#   '가게',
#   '연',
#   '연남',
#   '연남동',
#   '남동',
#   '동',
#   '1953',
#   '1953년',
#   '년',
#   '연남서',
#   '남서',
#   '직',
#   '직영점',
#   '영점',
#   '당일',
#   '작압',
#   '고기',
#   '4',
#   '4시간',
#   '시간',
#   '숙성',
#   '숙성후',
#   '후',
#   '한정',
#   '한정수량',
#   '수량',
#   '판매',
#   '곳',
#   '주차장',
#   '주차',
#   '불편',
#   '갈비',
#   '양념',
#   '정자동'],
#  '624': ['어묵', '부산역'],
#  '625': ['가로수길'],
#  '626': ['신방동'],
#  '627': ['갈비', '합정'],
#  '628': ['고기', '고기집', '집', '양념', '갈비', '신사역'],
#  '629': ['의정부동'],
#  '630': ['갈비',
#   '양념',
#   '소스',
#   '갈비',
#   '고기',
#   '고기집',
#   '집',
#   '망원동',
#   '가격',
#   '맛',
#   '된장찌개',
#   '갈비',
#   '고기',
#   '고기집',
#   '집',
#   '망원동'],
#  '631': ['동선동5가'],
#  '632': ['참치', '불당동'],
#  '633': ['평내동'],
#  '634': ['nan'],
#  '635': ['카페', '커피', '팔탄면'],
#  '636': ['치킨', '반여동'],
# ...
#   '예약',
#   '방',
#   '손님',
#   '보일러',
#   '빼버리더라구',
#   '순식간',
#   '방바닥',
#   '평소',
#   '갈비탕',
#   '포장',
#   '맛',
#   '석',
#   '석갈비',
#   '갈비',
#   '갈비탕',
#   '세종시'],
#  '700': ['예약',
#   '예약제로',
#   '제로',
#   '진행',
#   '식전',
#   '양송이',
#   '양송이수프',
#   '수프',
#   '빵',
#   '제공',
#   '분위기',
#   '때',
#   '방문',
#   '곳',
#   '식사',
#   '수',
#   '카페',
#   '울산'],
#  '701': ['국수', '잔치', '잔치국수', '사가정'],
#  '702': ['목동동'],
#  '703': ['흑', '흑돼지', '돼지', '교동'],
#  '704': ['일광면'],
#  '705': ['삼겹살', '삼겹살무한리필', '무한', '리필', '완주'],
#  '706': ['컵', '컵밥', '밥', '을지로입구역'],
#  '707': ['버블', '버블티', '티', '대', '조대'],
#  '708': ['골목',
#   '골목식당',
#   '식당',
#   '백종',
#   '백종원',
#   '원',
#   '롱',
#   '롱피자집입',
#   '피자',
#   '집',
#   '입',
#   '니',
#   '당',
#   '곳',
#   '사람',
#   '벙',
#   '벙말',
#   '말',
#   '웨이팅',
#   '번째',
#   '시도',
#   '시도만',
#   '만',
#   '11',
#   '11시오픈이지만',
#   '시',
#   '오픈',
#   '이지만',
#   '9',
#   '9시반정도',
#   '반',
#   '정도',
#   '줄',
#   '저',
#   '11시쯤',
#   '쯤',
#   '대기표',
#   '이름',
#   '2',
#   '30',
#   '30분쯤',
#   '분',
#   '점심',
#   '마지막',
#   '손님',
#   '내부',
#   '테이블',
#   '만큼',
#   '소란',
#   '백종원피',
#   '원피',
#   '디아블로',
#   '맛',
#   '특이',
#   '계란',
#   '노른자',
#   '퐁듀',
#   '도',
#   '도우',
#   '우',
#   '수',
#   '재미',
#   '소고',
#   '소고기와',
#   '기와',
#   '소스',
#   '살',
#   '핫',
#   '핫소스',
#   '밥',
#   '먹지',
#   '피자맛',
#   '분위기',
#   '만족',
#   '사장님',
#   '법',
#   '등',
#   '친절',
#   '기분',
#   '가격',
#   '한판',
#   '10000',
#   '10000만',
#   '만',
#   '초반',
#   '다음',
#   '피자',
#   '펍',
#   '역곡'],
#  '709': ['초밥', '샐러드', '호원동'],
#  '710': ['돼지', '돼지갈비', '갈비', '반야월'],
#  '711': ['괴정동'],
#  '712': ['합정동'],
#  '713': ['고추장', '고추장삼겹살', '삼겹살', '대패', '대패삼겹살', '청주'],
#  '714': ['멸치',
#   '멸치육수',
#   '육수',
#   '애호박',
#   '어가',
#   '김밥',
#   '내',
#   '내기준',
#   '기준',
#   '국수',
#   '왕만두',
#   '상무지구'],
#  '715': ['족발', '방촌동'],
#  '716': ['학생',
#   '로',
#   '곳',
#   '중',
#   '하나',
#   '하나임',
#   '임',
#   '3000',
#   '3000원대',
#   '원대',
#   '가격',
#   '사이즈',
#   '정도',
#   '정도임',
#   '메뉴',
#   '다양',
#   '펄',
#   '추가',
#   '종류',
#   '개인',
#   '취향',
#   '듯',
#   '함',
#   '교대'],
#  '718': ['주방',
#   '도',
#   '도우',
#   '우',
#   '반죽',
#   '요리',
#   '수',
#   '저',
#   '입',
#   '리',
#   '리조',
#   '조',
#   '맛',
#   '현덕면'],
#  '719': ['곱창', '나운동'],
#  '720': ['화덕', '화덕피자', '피자', '파스타', '금정구'],
#  '721': ['화덕', '화덕피자', '피자', '파스타', '양산'],
#  '722': ['파스타', '피자', '온천장'],
#  '723': ['나폴리', '나폴리피자', '피자', '이탈', '이탈리안레스토랑', '리', '안', '레스토랑', '울주군'],
#  '724': ['직원',
#   '직원분',
#   '분',
#   '친절',
#   '사람',
#   '때',
#   '분위기',
#   '저녁',
#   '야외',
#   '야외테라스',
#   '테라스',
#   '만족',
#   '술집',
#   '펍',
#   '서면'],
#  '725': ['미나리', '미나리삼겹살', '삼겹살', '첨단'],
#  '726': ['딱새', '딱새우회', '우회', '술집', '서면'],
#  '727': ['술집', '천호'],
#  '728': ['닭', '마산'],
#  '729': ['두산동'],
#  '730': ['마산회원구'],
#  '731': ['뷔페', '종로'],
#  '732': ['뷔페', '광화문'],
#  '733': ['화덕', '화덕피자', '피자', '은행동'],
#  '734': ['빵집', '치아', '치아바', '바', '상계동'],
#  '735': ['술집', '맥주', '까치산'],
#  '736': ['갈비', '국밥', '충무로'],
#  '737': ['분위기',
#   '가벼운',
#   '위스키',
#   '진',
#   '럼',
#   '등',
#   '수',
#   '루프',
#   '루프탑라운지',
#   '탑',
#   '라운지',
#   '술집',
#   '탄방동',
#   '분위기',
#   '바',
#   '소규모',
#   '가기',
#   '루프',
#   '루프탑라운지',
#   '탑',
#   '라운지',
#   '술집',
#   '탄방동',
#   '모',
#   '모히',
#   '히',
#   '라',
#   '라임잎',
#   '임',
#   '잎',
#   '상태',
#   '어이',
#   '위',
#   '데',
#   '데코',
#   '코',
#   '거',
#   '저지',
#   '저지경',
#   '경',
#   '생각',
#   '술',
#   '루프',
#   '루프탑라운지',
#   '탑',
#   '라운지',
#   '술집',
#   '탄방동'],
#  '738': ['루프', '루프탑라운지', '탑', '라운지', '술집', '평택'],
#  '739': ['루프', '루프탑라운지', '탑', '라운지', '술집', '세종시'],
#  '740': ['루프', '루프탑', '탑', '카페', '하남'],
#  '741': ['엘리베이터',
#   '안',
#   '5',
#   '5시',
#   '시',
#   '오픈',
#   '6',
#   '6시',
#   '시간',
#   '시간수정',
#   '수정',
#   '영업',
#   '영업시간',
#   '웹',
#   '불쾌',
#   '루프',
#   '루프탑라운지',
#   '탑',
#   '라운지',
#   '술집',
#   '두정동'],
#  '742': ['망고',
#   '망고칵테일',
#   '칵테일',
#   '정확',
#   '이름',
#   '기억',
#   '기억안',
#   '안',
#   '분위기',
#   '젛았어',
#   '루프',
#   '루프탑라운지',
#   '탑',
#   '라운지',
#   '칵테일',
#   '홍대'],
#  '743': ['인생',
#   '감',
#   '감바스',
#   '바스',
#   '만난',
#   '만난집',
#   '집',
#   '감바스',
#   '번',
#   '여기',
#   '새우',
#   '통',
#   '통통',
#   '곳',
#   '처음',
#   '가면',
#   '루프',
#   '루프탑',
#   '탑',
#   '가격',
#   '날씨',
#   '날',
#   '루프',
#   '루프탑라운지',
#   '탑',
#   '라운지',
#   '칵테일',
#   '잠실'],
#  '744': ['부채살',
#   '스테이크',
#   '토마토',
#   '토마토소스파게티',
#   '소',
#   '스파게티',
#   '김치',
#   '김치리소',
#   '리소',
#   '맛있엇어',
#   '아메리카',
#   '아메리카노랑',
#   '노랑',
#   '다음',
#   '여자',
#   '여자친구',
#   '친구',
#   '데이트',
#   '때',
#   '여기',
#   'ㅎ',
#   '루프',
#   '루프탑라운지',
#   '탑',
#   '라운지',
#   '술집',
#   '청주'],
#  '745': ['구들',
#   '데이트',
#   '음식',
#   '음식메뉴',
#   '메뉴',
#   '칵테일',
#   '단맛',
#   '맥주',
#   '추천',
#   '루프',
#   '루프탑라운지',
#   '탑',
#   '라운지',
#   '술집',
#   '논현'],
#  '746': ['루프', '루프탑라운지', '탑', '라운지', '술집', '인계동'],
#  '747': ['루프', '루프탑라운지', '탑', '라운지', '술집', '유성'],
#  '748': ['가족',
#   '휴일',
#   '방문',
#   '늘그막',
#   '풍경',
#   '날',
#   '가족단위',
#   '단위',
#   '오드',
#   '오드라군',
#   '라군',
#   '카페',
#   '당고',
#   '대전'],
#  '749': ['고기', '고기뷔페', '뷔페', '고기무한리필', '무한', '리필', '용인'],
#  '750': ['샐러드', '샐러드바', '바', '돼지고기', '영종도'],
#  '751': ['고기', '고기무한리필', '무한', '리필', '고기집', '집', '광교'],
#  '753': ['고기', '고기부페', '부', '페', '고기집', '집', '서현역'],
#  '754': ['고기', '고기무한리필', '무한', '리필', '고기집', '집', '홍대'],
#  '755': ['고기', '고기무한리필', '무한', '리필', '고기뷔페', '뷔페', '용인'],
#  '756': ['고기', '고기뷔페', '뷔페', '고기무한리필', '무한', '리필', '전대후문'],
#  '757': ['고기', '고기무한리필', '무한', '리필', '목살', '군산'],
#  '758': ['고기', '고기무한리필', '무한', '리필', '갈매기', '경성대'],
#  '759': ['정동면'],
#  '760': ['장항동'],
#  '761': ['일동'],
#  '762': ['연어', '누룽지', '본오동'],
#  '763': ['남면'],
#  '764': ['비하동'],
#  '765': ['사실', '밥', '기대', '은', '가게', '맛', '불고기', 'ddp'],
#  '766': ['nan'],
#  '767': ['양', '양꼬치', '꼬치', '심곡동'],
#  '768': ['고기', '고기집', '집', '버섯', '이태원'],
#  '769': ['치킨', '면목'],
#  '770': ['옛날', '옛날통닭', '통닭', '위례'],
#  '771': ['통닭', '옛날', '옛날통닭', '오류동'],
#  '772': ['병점동'],
#  '773': ['중산동'],
#  '774': ['돈까스', '안국역'],
#  '775': ['국밥', '인후동1가'],
#  '776': ['닭', '바베큐', '바베큐치킨', '치킨', '양정'],
#  '777': ['통닭', '시청'],
#  '778': ['지곶동'],
#  '779': ['원동'],
#  '780': ['창전동'],
#  '781': ['누읍동'],
#  '782': ['송탄'],
#  '783': ['포차', '술집', '강남역'],
#  '784': ['술집', '이자', '금호동'],
#  '785': ['술집', '스테이크', '명동'],
#  '786': ['서빙',
#   '분',
#   '친절',
#   '데',
#   '가게',
#   '코앞',
#   '느낌',
#   '전체적',
#   '분위기',
#   '이국적',
#   '느낌있음',
#   '있음',
#   '음식',
#   '주류',
#   '듯',
#   '수제',
#   '수제버거',
#   '버거',
#   '카페',
#   '경리단길'],
#  '787': ['리',
#   '리조또에',
#   '조',
#   '또에',
#   '새우',
#   '게살',
#   '크림',
#   '파스타',
#   '게살향',
#   '향',
#   '맛',
#   '이벤트',
#   '참여',
#   '참여하미',
#   '하미',
#   '음료',
#   '파스타',
#   '객리단길'],
#  '788': ['서정동'],
#  '789': ['돼지고기', '하소동'],
#  '790': ['고',
#   '고깃집',
#   '깃',
#   '집',
#   '차원',
#   '집이',
#   '부천',
#   '달',
#   '번',
#   '고기',
#   '고기',
#   '고기집',
#   '집',
#   '흑',
#   '흑돼지',
#   '돼지',
#   '송도'],
#  '791': ['궐동'],
#  '792': ['모밀', '수완지구'],
#  '793': ['수택동'],
#  '794': ['커피', '카페', '나주'],
#  '795': ['내곡동'],
#  '796': ['피맥', '익산'],
#  '797': ['돈까스', '옛날', '옛날돈까스', '광안'],
#  '798': ['분위기',
#   '짱',
#   '사람',
#   '사진',
#   '음식',
#   '음식맛',
#   '맛',
#   '쏘쏘했습니',
#   '한옥',
#   '한옥카페',
#   '카페',
#   '대구'],
#  '799': ['와부읍'],
#  '800': ['케이크', '구미동'],
#  '801': ['펍', '순천'],
#  '802': ['코', '맥주', '경상대'],
#  '803': ['존',
#   '존맛',
#   '맛',
#   '세트',
#   '세트메뉴',
#   '메뉴',
#   '거',
#   '추천',
#   '자주',
#   '자주가게',
#   '가게',
#   '파스타',
#   '경대북문',
#   '맛',
#   '무엇',
#   '대학로',
#   '가격',
#   '쌈',
#   '파스타',
#   '경대북문'],
#  '804': ['피자', '피자집', '집', '남일동'],
#  '805': ['범어동'],
#  '806': ['방화동'],
#  '807': ['덕계'],
#  '808': ['화덕', '화덕피자', '피자', '신기동'],
#  '809': ['나성동'],
#  '810': ['지산동'],
#  '811': ['커피', '삼척'],
#  '812': ['피자',
#   '피자가격',
#   '가격',
#   '2',
#   '2층',
#   '층',
#   '테라스',
#   '경치',
#   '커피',
#   '커피마시기',
#   '마',
#   '시기',
#   '커피',
#   '카페',
#   '영천'],
#  '813': ['사동'],
#  '814': ['김치찌개', '목동동'],
#  '815': ['여기',
#   '야쿠',
#   '우동',
#   '샤브샤브',
#   '거',
#   '안',
#   '재료',
#   '국물',
#   '면',
#   '그릇',
#   '처음',
#   '왜케',
#   '퀄리티',
#   '수긍',
#   '돈',
#   '돈부리',
#   '부리',
#   '우동',
#   '옥수'],
#  '816': ['별내동'],
#  '817': ['대구대'],
#  '818': ['비',
#   '비싸요',
#   '싸요',
#   '사람',
#   '서비스',
#   '서비스면',
#   '면',
#   '요',
#   '외국',
#   '구들',
#   '베이커리',
#   '베이커리카페',
#   '카페',
#   '창원가로수길',
#   '인테리어',
#   '음료',
#   '종류',
#   '베이커리',
#   '베이커리카페',
#   '카페',
#   '창원가로수길',
#   '테이블',
#   '수',
#   '사람',
#   '뷱',
#   '뷱적',
#   '적',
#   '베이커리',
#   '베이커리카페',
#   '카페',
#   '창원가로수길'],
#  '819': ['김해시'],
#  '820': ['부대', '부대찌개', '찌개', '수택동'],
#  '821': ['카페', '김포공항'],
#  '822': ['부천대'],
#  '823': ['포차', '소주', '홍대'],
#  '824': ['산', '산꼼장어', '꼼장어', '간석동'],
#  '825': ['신당동'],
#  '826': ['떡볶이', '신림'],
#  '827': ['분식', '떡볶이', '상도동'],
#  '828': ['분식', '용현동'],
#  '829': ['강남'],
#  '830': ['사장님',
#   '친절',
#   '된장찌개',
#   '순두부',
#   '부추',
#   '고기',
#   '최고',
#   '통',
#   '통삼겹',
#   '삼',
#   '겹',
#   '시립대'],
#  '831': ['상계동'],
#  '832': ['떡볶이', '창동'],
#  '833': ['갈곶동'],
#  '834': ['수플레',
#   '팬',
#   '팬케이크',
#   '케이크',
#   '처음',
#   '가격',
#   '데',
#   '맛',
#   '밀크',
#   '밀크티',
#   '티',
#   '저',
#   '입맛',
#   '안',
#   '안맞앗',
#   '맞앗',
#   '밀크',
#   '밀크티',
#   '티',
#   '수플레',
#   '월남동5가'],
#  '835': ['밀크', '밀크티', '티', '카페', '인계동'],
#  '836': ['한동안',
#   '핫',
#   '카페',
#   '체인',
#   '방문',
#   '수플레',
#   '입',
#   '맛',
#   '40',
#   '40분',
#   '분',
#   '밀가루',
#   '음료',
#   '기억',
#   '브라운',
#   '브라운슈',
#   '슈',
#   '밀크',
#   '밀크티',
#   '티',
#   '감',
#   '사장님',
#   '친절',
#   '뭐',
#   '지점',
#   '청주',
#   '19',
#   '19티',
#   '추천',
#   '비지떡',
#   '그',
#   '돈',
#   '밀크',
#   '밀크티',
#   '티',
#   '카페',
#   '청주'],
#  '837': ['팬', '팬케이크', '케이크', '밀크', '밀크티', '티', '안산중앙역'],
#  '838': ['밀크',
#   '밀크티',
#   '티',
#   '병이',
#   '이색적',
#   '성비',
#   '수플레',
#   '짱',
#   '짱맛',
#   '맛',
#   '밀크',
#   '밀크티',
#   '티',
#   '팬',
#   '팬케이크',
#   '케이크',
#   '부천역'],
#  '839': ['팬', '팬케이크', '케이크', '밀크', '밀크티', '티', '서현동'],
#  '840': ['팬', '팬케이크', '케이크', '밀크', '밀크티', '티', '사동'],
#  '841': ['팬', '팬케이크', '케이크', '카페', '동선동2가'],
#  '842': ['친절',
#   '성비',
#   '밀크',
#   '밀크티',
#   '티',
#   '아이스',
#   '아이스크림',
#   '크림',
#   '2',
#   '2천원',
#   '천',
#   '원',
#   '3',
#   '3천원',
#   '수',
#   '밀크',
#   '밀크티',
#   '티',
#   '팬',
#   '팬케이크',
#   '케이크',
#   '강남역',
#   '별',
#   '맛',
#   '향이',
#   '강',
#   '타입',
#   '흑당',
#   '바닐라',
#   '단',
#   '단맛',
#   '옛날',
#   '여기',
#   '데',
#   '타이거',
#   '슈가',
#   '수요',
#   '주말',
#   '웨이팅',
#   '자리',
#   '밀크',
#   '밀크티',
#   '티',
#   '팬',
#   '팬케이크',
#   '케이크',
#   '강남역',
#   '내부',
#   '생각',
#   '버블',
#   '버블티',
#   '티',
#   '입',
#   '안',
#   '수플레',
#   '수플레팬케이',
#   '팬',
#   '케이',
#   '달걀',
#   '달걀냄새',
#   '냄새',
#   '과일',
#   '맛',
#   '서서',
#   '밀크',
#   '밀크티',
#   '티',
#   '팬',
#   '팬케이크',
#   '케이크',
#   '강남역',
#   '수플레',
#   '밀크',
#   '밀크티',
#   '티',
#   '맛',
#   '나',
#   '진',
#   '에어컨',
#   '세서',
#   '뻔',
#   '밀크',
#   '밀크티',
#   '티',
#   '팬',
#   '팬케이크',
#   '케이크',
#   '강남역',
#   '때',
#   '방문',
#   '곳',
#   '팬',
#   '팬케이크',
#   '케이크',
#   '유명',
#   '건',
#   '테이블',
#   '테이크',
#   '테이크아웃',
#   '아웃',
#   '밀크',
#   '밀크티',
#   '티',
#   '팬',
#   '팬케이크',
#   '케이크',
#   '강남역'],
#  '843': ['펍', '홍대'],
#  '844': ['교문동'],
#  '845': ['카페', '아이스', '메리', '메리카노', '카', '노', '상수'],
#  '846': ['반송동'],
#  '847': ['카페', '홍대'],
#  '848': ['갈매동'],
#  '849': ['금오동'],
#  '850': ['술집', '연남동'],
#  '851': ['의정부'],
#  '852': ['1',
#   '1층',
#   '층',
#   '왼쪽',
#   '카페',
#   '뜻',
#   '뜻이래',
#   '이래',
#   '99',
#   '99플라워',
#   '플라워',
#   '건물',
#   '일',
#   '건물자체',
#   '자체',
#   '디자인',
#   '사이즈',
#   '창',
#   '양재',
#   '양재근린공원',
#   '근린',
#   '공원',
#   '나무',
#   '오렌지',
#   '슈페너',
#   '오렌지조각',
#   '조각',
#   '나무숟가락',
#   '숟가락',
#   '테이블',
#   '대리석',
#   '대리석스탈',
#   '스탈',
#   '의자',
#   '철제',
#   '철제스탈',
#   '12',
#   '3',
#   '3시',
#   '시',
#   '직장인',
#   '직장인분',
#   '분',
#   '6',
#   '6시',
#   '혼자',
#   '책',
#   '거',
#   '선호',
#   '입구',
#   '입구쪽',
#   '쪽',
#   '집',
#   '안보',
#   '1000',
#   '1000원',
#   '원',
#   '교환',
#   '수',
#   '모',
#   '모찌',
#   '찌',
#   '카페',
#   '양재동'],
#  '853': ['대안동'],
#  '854': ['침산동'],
#  '855': ['삼겹살', '돼지고기', '칠곡'],
#  '856': ['지하', '커피', '메뉴', 'ㅠ', '가격', '양이', '카페', '경대북문'],
#  '858': ['노', '카페', '성서'],
#  '859': ['츄러스', '아이스', '아이스크림', '크림', '대학로'],
#  '860': ['츄러스', '누', '누텔라', '텔', '라', '강남역'],
#  '861': ['카페', '츄', '츄러', '러', '명지대'],
#  '862': ['츄러스', '디저트', '삼청동'],
#  '863': ['카페', '감정동'],
#  '864': ['레스토랑', '피자', '내동'],
#  '865': ['커피', '카페', '전대후문'],
#  '866': ['칵테일', '칵테일바', '바', '목동역'],
#  '867': ['1',
#   '맛',
#   '크림',
#   '크림파스타',
#   '파스타',
#   '냄새',
#   '예',
#   '소이',
#   '은',
#   '일행',
#   '듯',
#   '2',
#   '분위기',
#   '조명',
#   '사진',
#   '3',
#   '기타',
#   '음식',
#   '별개',
#   '직원',
#   '직원분',
#   '분',
#   '절해',
#   '후식',
#   '음료',
#   '선택',
#   '가능',
#   '연어',
#   '연어피자',
#   '피자',
#   '필',
#   '필라프',
#   '라프',
#   '충장로',
#   '처음',
#   '파스타',
#   '보고',
#   '플레이팅',
#   '연어',
#   '연어피자',
#   '피자',
#   '필',
#   '필라프',
#   '라프',
#   '충장로'],
#  '868': ['핸드', '핸드드립커피', '드립', '커피', '카페', '신포동'],
#  '869': ['갈매기', '갈매기살', '살', '우', '우삼겹', '삼', '겹', '영등포'],
#  '870': ['호평동'],
#  '871': ['방배동'],
#  '872': ['옛날', '옛날통닭', '통닭', '치킨', '대전'],
#  '873': ['카페', '구미'],
#  '874': ['맥주집', '치킨', '광양읍'],
#  '875': ['얼마', '곳', '맥주집', '이야기', '수', '맥주', '편', '화장실', '맥주', '호프', '전주'],
#  '876': ['생연동'],
#  '877': ['가마솥', '돼지', '돼지국밥', '국밥', '율하'],
#  '878': ['동부면'],
#  '879': ['국물', '국물닭발', '닭', '발', '동탄'],
#  '880': ['대게', '킹크', '킹크랩', '랩', '기장시장'],
#  '881': ['대패', '대패삼겹살', '삼겹살', '해물', '해물라면', '라면', '광화동'],
#  '882': ['삼겹살', '장유'],
#  '883': ['천호동'],
#  '884': ['농촌',
#   '곳',
#   '위치',
#   '각각',
#   '메뉴',
#   '중',
#   '중급이상',
#   '급',
#   '이상',
#   '맛',
#   '회무',
#   '회무침은',
#   '침은',
#   '개인적',
#   '낮',
#   '낮술한잔',
#   '술',
#   '한잔',
#   '한식',
#   '한식뷔페',
#   '뷔페',
#   '육회',
#   '전남무안'],
#  '885': ['횟집', '광주'],
#  '886': ['숯불', '숯불갈비', '갈비', '괴정'],
#  '887': ['효목동'],
#  '888': ['현동'],
#  '889': ['해운동'],
#  '890': ['랍스', '해물', '해물찜', '찜', '광안리'],
#  '891': ['길동'],
#  '892': ['심곡동'],
#  '893': ['충주'],
#  '894': ['교동'],
#  '895': ['상현동'],
#  '896': ['녹양동'],
#  '897': ['내동'],
#  '898': ['생연동'],
#  '899': ['삼덕동1가'],
#  '900': ['오포읍'],
#  '901': ['황금동'],
#  '902': ['동면'],
#  '903': ['상동면'],
#  '904': ['칠암동'],
#  '905': ['신월동'],
#  '906': ['서면'],
#  '907': ['오리', '오리구이', '구이', '밀양'],
#  '908': ['감자탕', '아이스', '아이스크림', '크림', '영주'],
#  '909': ['커피', '짬뽕', '원주'],
#  '910': ['제육', '제육볶음', '볶음', '짬뽕', '군산'],
#  '911': ['삼', '삼합', '합', '키조개', '장흥'],
#  '912': ['닭', '닭갈비', '갈비', '중국집', '춘천'],
#  '913': ['뼈', '뼈해장국', '해장국', '중화', '중화요리', '요리', '쌍촌동'],
#  '914': ['바베큐', '안산'],
#  '915': ['도토리', '도토리묵', '묵', '레스토랑', '해남'],
#  '916': ['수성동'],
#  '917': ['조개', '조개찜', '찜', '거제'],
#  '918': ['꼬막', '꼬막정식', '정식', '벌교'],
#  '919': ['닭', '닭갈비', '갈비', '철판', '철판닭갈비', '강촌'],
#  '920': ['전라도',
#   '전라도민',
#   '민',
#   '인정',
#   '꼬막',
#   '꼬막집',
#   '집',
#   '음식',
#   '음식전체',
#   '전체',
#   '간',
#   '사장님',
#   '친절',
#   '인근',
#   '인근주차장',
#   '주차장',
#   '주차',
#   '주차하면',
#   '하면',
#   '주차비',
#   '비',
#   '돈',
#   '꼬막',
#   '꼬막정식',
#   '정식',
#   '온천장'],
#  '921': ['대방동'],
#  '922': ['직', '직화구', '화구', '돼지', '돼지갈비', '갈비', '근북면'],
#  '923': ['삼정동'],
#  '924': ['남면'],
#  '925': ['조개', '조개찜', '찜', '거제도'],
#  '926': ['원주'],
#  '927': ['짬뽕', '강화도'],
#  '928': ['고암동'],
#  '929': ['구로동'],
#  '930': ['광명동'],
#  '931': ['이충동'],
#  '932': ['대림1동'],
#  '933': ['거제도'],
#  '934': ['횟집', '방어회', '내동'],
#  '935': ['장유'],
#  '936': ['용원동'],
#  '937': ['김해시'],
#  '938': ['장어', '귀래면'],
#  '939': ['거여동'],
#  '940': ['찌개', '서정동'],
#  '941': ['사림동'],
#  '942': ['포차', '술집', '평택'],
#  '943': ['화도읍'],
#  '944': ['해장국', '청주'],
#  '945': ['떡볶이', '치즈', '창곡동'],
#  '946': ['이매동'],
#  '947': ['족발', '국밥', '구포시장'],
#  '948': ['사동'],
#  '949': ['닭', '닭갈비', '갈비', '신당동'],
#  '950': ['조개', '조개구이', '구이', '무', '리필', '리필조개구이', '대천해수욕장'],
#  '951': ['돈까스', '남산타워'],
#  '952': ['덕계동'],
#  '953': ['삼방동'],
#  '954': ['삼계동'],
#  '955': ['신갈동'],
#  '956': ['nan'],
#  '957': ['봉천동'],
#  '958': ['조개', '조개찜', '찜', '칼국수', '대부도'],
#  '959': ['새우', '새우튀김', '튀김', '대포항'],
#  '960': ['부발읍'],
#  '961': ['닭새우', '꽃새우', '동해'],
#  '962': ['먹', '먹태구이', '태', '구이', '맥주집', '부산대'],
#  '963': ['가능동'],
#  '964': ['민락동'],
#  '965': ['카페', '내부', '삼각대', '비치', '맛', '좋앗', '좋앗어용', '어용', '카페', '수성동4가'],
#  '966': ['일식당', '모듬', '모듬사시미', '사시미', '망원동'],
#  '967': ['평택동'],
#  '968': ['신장동'],
#  '969': ['본오동'],
#  '970': ['치킨', '후암동'],
#  '971': ['풍광',
#   '특색',
#   '레스토랑',
#   '고급',
#   '자연',
#   '인테리어',
#   '풍경',
#   '기쁨',
#   '스텝',
#   '릴',
#   '릴렉스',
#   '렉스',
#   '전체',
#   '전체분위기',
#   '분위기',
#   '서비스',
#   '실망',
#   '창',
#   '밖',
#   '식사',
#   '분',
#   '듯',
#   '퓨',
#   '퓨전레스토랑',
#   '전',
#   '레스토랑',
#   '카페',
#   '은평'],
#  '972': ['한옥',
#   '한옥뷰',
#   '뷰',
#   '수',
#   '곳',
#   '사람',
#   '때',
#   '한옥',
#   '한옥카페',
#   '카페',
#   '은평',
#   '북한산',
#   '뷰',
#   '환상',
#   '환상적임',
#   '적임',
#   '가격',
#   '사악',
#   '이해',
#   '맛',
#   '보통',
#   '이상은',
#   '함',
#   '부모님',
#   '가기',
#   '곳',
#   '좌석',
#   '떡',
#   '2',
#   '2개',
#   '개',
#   '반',
#   '4',
#   '4피스',
#   '피스',
#   '5500',
#   '한옥',
#   '한옥카페',
#   '카페',
#   '은평',
#   '뷰',
#   '한데',
#   '맛',
#   '무엇',
#   '슈페너',
#   '한옥',
#   '한옥카페',
#   '카페',
#   '은평',
#   '주문',
#   '1',
#   '1층',
#   '층',
#   '2',
#   '2층',
#   '5',
#   '5층',
#   '진동',
#   '진동벨',
#   '벨',
#   '소문',
#   '뷰',
#   '커피',
#   '커피맛',
#   '맛',
#   '한옥',
#   '한옥카페',
#   '카페',
#   '은평'],
#  '973': ['원미동'],
#  '974': ['군산'],
#  '975': ['양촌읍'],
#  '976': ['대화동'],
#  '977': ['심곡동'],
#  '978': ['장항동'],
#  '979': ['둔촌동'],
#  '980': ['갈비찜', '냉면', '의정부'],
#  '981': ['튀김', '갈비찜', '경희대'],
#  '982': ['지', '지갈비', '갈비', '면목'],
#  '983': ['nan'],
#  '984': ['상도동'],
#  '985': ['화곡동'],
#  '986': ['자양동'],
#  '987': ['지', '지갈비', '갈비', '관악'],
#  '988': ['건대'],
#  '989': ['왕십리'],
#  '990': ['죽도동'],
#  '991': ['배달', '배달전문', '전문', '냉면', '창동'],
#  '992': ['서정동'],
#  '993': ['뼈', '뼈해장국', '해장국', '곡반정동'],
#  '994': ['감자탕', '봉일천'],
#  '995': ['뼈', '뼈해장국', '해장국', '야탑'],
#  '996': ['화성시'],
#  '997': ['뼈', '뼈해장국', '해장국', '남산타워'],
#  '998': ['뼈', '뼈해장국', '해장국', '수원대'],
#  '999': ['뼈',
#   '뼈해장국',
#   '해장국',
#   '개인용',
#   '감자탕',
#   '보',
#   '보먄',
#   '먄',
#   '과',
#   '고',
#   '소스',
#   '박지',
#   '꿀',
#   '꿀맛',
#   '맛',
#   '해물',
#   '해물찜',
#   '찜',
#   '별',
#   '집',
#   '감자탕',
#   '수원'],
#  '1000': ['뼈', '뼈해장국', '해장국', '안산'],
#  '1001': ['독산동'],
#  '1002': ['감자탕', '영통동'],
#  '1003': ['원동'],
#  '1004': ['병점'],
#  '1005': ['숯불', '숯불구이', '구이', '돼지', '돼지갈비', '갈비', '동삭동'],
#  '1006': ['수청동'],
#  '1007': ['외동'],
#  ...}

# %%
tfidf = TfidfVectorizer(max_features = 100, max_df=0.95, min_df=0)

#generate tf-idf term-document matrix
A_tfidf_sp = tfidf.fit_transform(documents)  #size D x V

# %%
#tf-idf dictionary    
tfidf_dict = tfidf.get_feature_names()
print(tfidf_dict)
# Out:
# ['nan', '가게', '가격', '갈비', '고기', '고기집', '곱창', '구이', '국물', '국밥', '국수', '김밥', '김치', '꼬치', '냉면', '느낌', '닭갈비', '대구', '돈까스', '돼지', '돼지갈비', '디저트', '떡볶이', '레스토랑', '리필', '만두', '맛집', '맥주', '메뉴', '무한', '반찬', '방문', '버거', '보쌈', '볶음', '볶음밥', '분위기', '불고기', '브런', '비빔밥', '사람', '사장님', '삼겹살', '샐러드', '생각', '서비스', '성비', '소고기', '손님', '수제', '순대', '술집', '스테이크', '시간', '식당', '식사', '양념', '여기', '요리', '유명', '음식', '이자', '일산', '있음', '장어', '전골', '전문', '전주', '정도', '정식', '족발', '주문', '주차', '중국집', '직원', '짬뽕', '찌개', '처음', '청주', '초밥', '추천', '치즈', '치킨', '친절', '카페', '칼국수', '커피', '케이크', '크림', '탕수육', '테이블', '튀김', '파스타', '피자', '하나', '한우', '해물', '해장국', '홍대', '횟집']

# %%
data_array = A_tfidf_sp.toarray()
data = pd.DataFrame(data_array, columns=tfidf_dict)
data.shape
# Out:
# (456599, 100)

# %%
cosine_similarities = linear_kernel(A_tfidf_sp, A_tfidf_sp)

# %%
json_list = []
for key, item in json_data.items():
    new_item = ''
    for s in item:
        new_item += ' ' + s
    json_list.append([key, new_item])

# %%
data = pd.DataFrame(json_list, columns=['store_id', 'content'])

# %%
tf = TfidfVectorizer()
tfidf_matrix = tf.fit_transform(data['content'])

# %%
print(data['content'])
# Out:
# 0              아구 아구찜 찜 포장마차 홍대
# 1                         카페 광주
# 2          피 피쉬앤칩스 쉬 앤 칩스 펍 이태원
# 3            레스토랑 카프 카프레 레 달맞이길
# 4              디저트 디저트카페 카페 발산역
#                   ...
# 456594                      녹양동
# 456595                      안중읍
# 456596                      퇴촌면
# 456597                      소주동
# 456598                     의정부동
# Name: content, Length: 456599, dtype: object

# %%
tfidfv = TfidfVectorizer().fit(data['content'])
print(tfidfv.transform(corpus).toarray())
print(tfidfv.vocabulary_)

# %%
print(tfidfv.transform(corpus))

# %%
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)
results = {}
for idx, row in ds.iterrows():
   similar_indices = cosine_similarities[idx].argsort()[:-100:-1] 
   similar_items = [(cosine_similarities[idx][i], data['store_id'][i]) for i in similar_indices] 
   results[row['id']] = similar_items[1:]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-235-f6fd73019c7d> in <module>
# ----> 1 cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in linear_kernel(X, Y, dense_output)
#     990     """
#     991     X, Y = check_pairwise_arrays(X, Y)
# --> 992     return safe_sparse_dot(X, Y.T, dense_output=dense_output)
#     993
#     994
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     149             ret = np.dot(a, b)
#     150     else:
# --> 151         ret = a @ b
#     152
#     153     if (sparse.issparse(a) and sparse.issparse(b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\base.py in __matmul__(self, other)
#     562             raise ValueError("Scalar operands are not allowed, "
#     563                              "use '*' instead")
# --> 564         return self.__mul__(other)
#     565
#     566     def __rmatmul__(self, other):
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\base.py in __mul__(self, other)
#     482             if self.shape[1] != other.shape[0]:
#     483                 raise ValueError('dimension mismatch')
# --> 484             return self._mul_sparse_matrix(other)
#     485
#     486         # If it's a list or whatever, treat it like a matrix
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\compressed.py in _mul_sparse_matrix(self, other)
#     514                                     maxval=nnz)
#     515         indptr = np.asarray(indptr, dtype=idx_dtype)
# --> 516         indices = np.empty(nnz, dtype=idx_dtype)
#     517         data = np.empty(nnz, dtype=upcast(self.dtype, other.dtype))
#     518
#
# MemoryError: Unable to allocate 26.3 GiB for an array with shape (3536218231,) and data type int64

# %% [markdown]
# # OKT

# %%
okt = Okt()

# %%
okt_content = {}
for idx, review in reviews.iterrows():
    if review['content']:
        content = [noun for noun in (okt.nouns(f"u{review['content']}"))]
        content.extend(okt.nouns(f"u{review['category']}"))
        content.append(review['area'])
        if okt_content.get(review['store_id']):
            okt_content[review['store_id']].extend(content)
        else:
            okt_content[review['store_id']] = content
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9aa4dee0b631> in <module>
#       1 okt_content = {}
# ----> 2 for idx, review in reviews.iterrows():
#       3     if review['content']:
#       4         content = [noun for noun in (okt.nouns(f"u{review['content']}"))]
#       5         content.extend(okt.nouns(f"u{review['category']}"))
#
# NameError: name 'reviews' is not defined

# %%
with open('okt_data.json', 'w', encoding='utf-8') as make_file:
    json.dump(okt_content, make_file, indent="\t")

# %%
from sklearn.metrics.pairwise import linear_kernel

# %%
with open('okt_data.json', 'r') as f:
    okt_data = json.load(f)

# %%
okt_list = []
for key, item in okt_data.items():
    new_item = ''
    for s in item:
        new_item += ' ' + s
    okt_list.append([key, new_item])

# %%
data = pd.DataFrame(okt_list, columns=['store_id', 'content'])

# %%
tf = TfidfVectorizer(min_df=50)
tfidf_matrix = tf.fit_transform(data['content'])

# %%
tfidf_matrix.shape
# Out:
# (456599, 3951)

# %%
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)
results = {}
for idx, row in ds.iterrows():
   similar_indices = cosine_similarities[idx].argsort()[:-100:-1] 
   similar_items = [(cosine_similarities[idx][i], data['store_id'][i]) for i in similar_indices] 
   results[row['id']] = similar_items[1:]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-15-ea2aea77b668> in <module>
# ----> 1 cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)
#       2 results = {}
#       3 for idx, row in ds.iterrows():
#       4    similar_indices = cosine_similarities[idx].argsort()[:-100:-1]
#       5    similar_items = [(cosine_similarities[idx][i], data['store_id'][i]) for i in similar_indices]
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py in linear_kernel(X, Y, dense_output)
#     990     """
#     991     X, Y = check_pairwise_arrays(X, Y)
# --> 992     return safe_sparse_dot(X, Y.T, dense_output=dense_output)
#     993
#     994
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     149             ret = np.dot(a, b)
#     150     else:
# --> 151         ret = a @ b
#     152
#     153     if (sparse.issparse(a) and sparse.issparse(b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\base.py in __matmul__(self, other)
#     562             raise ValueError("Scalar operands are not allowed, "
#     563                              "use '*' instead")
# --> 564         return self.__mul__(other)
#     565
#     566     def __rmatmul__(self, other):
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\base.py in __mul__(self, other)
#     482             if self.shape[1] != other.shape[0]:
#     483                 raise ValueError('dimension mismatch')
# --> 484             return self._mul_sparse_matrix(other)
#     485
#     486         # If it's a list or whatever, treat it like a matrix
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\compressed.py in _mul_sparse_matrix(self, other)
#     515         indptr = np.asarray(indptr, dtype=idx_dtype)
#     516         indices = np.empty(nnz, dtype=idx_dtype)
# --> 517         data = np.empty(nnz, dtype=upcast(self.dtype, other.dtype))
#     518
#     519         fn = getattr(_sparsetools, self.format + '_matmat_pass2')
#
# MemoryError: Unable to allocate 24.8 GiB for an array with shape (3327147044,) and data type float64

# %%
corpus = data['content']
tfidfv = TfidfVectorizer().fit(corpus)
print(tfidfv.transform(corpus).toarray())
print(tfidfv.vocabulary_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fc11317ef10d> in <module>
# ----> 1 corpus = data['content']
#       2 tfidfv = TfidfVectorizer().fit(corpus)
#       3 print(tfidfv.transform(corpus).toarray())
#       4 print(tfidfv.vocabulary_)
#
# NameError: name 'data' is not defined
